# %% [markdown]
# This script takes as input the LSTM or RNN weights found by train.py
# change the path in line 176 of this script to point to the h5 file
# with LSTM or RNN weights generated by train.py
#
# Author: Niek Tax

# %%
from __future__ import division
import csv
import copy
import numpy as np
import distance
from itertools import izip, islice
import unicodecsv
from sklearn import metrics
from math import sqrt
import time
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from jellyfish._jellyfish import damerau_levenshtein_distance
from collections import Counter

# %%
from keras.models import load_model
from theano.ifelse import ifelse #added this
# Out:
# Using Theano backend.

# %% [markdown]
# # Read 1

# %%
eventlog = "helpdesk.csv"
lastcase = ''
line = ''
firstLine = True
lines = []
timeseqs = []
timeseqs2 = []
times = []
times2 = []
numlines = 0
casestarttime = None
lasteventtime = None

# %%
csvfile = open('../data/%s' % eventlog, 'r')
spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
next(spamreader, None)  # skip the headers
ascii_offset = 161

# %%
#for row in islice(spamreader, 0, 174):
for row in spamreader:
    t = time.strptime(row[2], "%Y-%m-%d %H:%M:%S")
    if row[0]!=lastcase:
        casestarttime = t
        lasteventtime = t
        lastcase = row[0]
        if not firstLine:        
            lines.append(line)
            timeseqs.append(times)
            timeseqs2.append(times2)
        line = ''
        times = []
        numlines+=1
    line+=unichr(int(row[1])+ascii_offset)
    timesincelastevent = datetime.fromtimestamp(time.mktime(t))-datetime.fromtimestamp(time.mktime(lasteventtime))
    timesincecasestart = datetime.fromtimestamp(time.mktime(t))-datetime.fromtimestamp(time.mktime(casestarttime))
    timediff = 86400 * timesincelastevent.days + timesincelastevent.seconds
    timediff2 = 86400 * timesincecasestart.days + timesincecasestart.seconds
    times.append(timediff)
    times2.append(timediff2)
    lasteventtime = t
    firstLine = False

# add last case
lines.append(line)
timeseqs.append(times)
timeseqs2.append(times2)
numlines+=1

# %%
divisor = np.mean([item for sublist in timeseqs for item in sublist])
print('divisor: {}'.format(divisor))
divisor2 = np.mean([item for sublist in timeseqs2 for item in sublist])
print('divisor2: {}'.format(divisor2))
# Out:
# divisor: 210915.519985
# divisor2: 409874.90124

# %%
elems_per_fold = int(round(numlines/3))
fold1 = lines[:elems_per_fold]
fold1_t = timeseqs[:elems_per_fold]
fold1_t2 = timeseqs2[:elems_per_fold]

fold2 = lines[elems_per_fold:2*elems_per_fold]
fold2_t = timeseqs[elems_per_fold:2*elems_per_fold]
fold2_t2 = timeseqs2[elems_per_fold:2*elems_per_fold]

lines = fold1 + fold2
lines_t = fold1_t + fold2_t
lines_t2 = fold1_t2 + fold2_t2

# %%
step = 1
sentences = []
softness = 0
next_chars = []
lines = map(lambda x: x+'!',lines)
maxlen = max(map(lambda x: len(x),lines))

chars = map(lambda x : set(x),lines)
chars = list(set().union(*chars))
chars.sort()
target_chars = copy.copy(chars)
chars.remove('!')
print('total chars: {}, target chars: {}'.format(len(chars), len(target_chars)))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
target_char_indices = dict((c, i) for i, c in enumerate(target_chars))
target_indices_char = dict((i, c) for i, c in enumerate(target_chars))
print(indices_char)
# Out:
# total chars: 9, target chars: 10
# {0: u'\xa2', 1: u'\xa3', 2: u'\xa4', 3: u'\xa5', 4: u'\xa6', 5: u'\xa7', 6: u'\xa8', 7: u'\xa9', 8: u'\xaa'}

# %% [markdown]
# # Read 2

# %%
lastcase = ''
line = ''
firstLine = True
lines = []
timeseqs = []  # relative time since previous event
timeseqs2 = [] # relative time since case start
timeseqs3 = [] # absolute time of previous event
times = []
times2 = []
times3 = []
numlines = 0
casestarttime = None
lasteventtime = None

# %%
csvfile = open('../data/%s' % eventlog, 'r')
spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
next(spamreader, None)  # skip the headers
# Out:
# ['CaseID', 'ActivityID', 'CompleteTimestamp']

# %%
#for row in islice(spamreader, 0, 174):
for row in spamreader:
    t = time.strptime(row[2], "%Y-%m-%d %H:%M:%S")
    if row[0]!=lastcase:
        casestarttime = t
        lasteventtime = t
        lastcase = row[0]
        if not firstLine:        
            lines.append(line)
            timeseqs.append(times)
            timeseqs2.append(times2)
            timeseqs3.append(times3)
        line = ''
        times = []
        times2 = [] #added this
        times3 = [] #added this
        numlines+=1
    line+=unichr(int(row[1])+ascii_offset)
    timesincelastevent = datetime.fromtimestamp(time.mktime(t))-datetime.fromtimestamp(time.mktime(lasteventtime))
    timesincecasestart = datetime.fromtimestamp(time.mktime(t))-datetime.fromtimestamp(time.mktime(casestarttime))
    midnight = datetime.fromtimestamp(time.mktime(t)).replace(hour=0, minute=0, second=0, microsecond=0)
    timesincemidnight = datetime.fromtimestamp(time.mktime(t))-midnight
    timediff = 86400 * timesincelastevent.days + timesincelastevent.seconds
    timediff2 = 86400 * timesincecasestart.days + timesincecasestart.seconds
    #timediff = log(timediff+1)
    times.append(timediff)
    times2.append(timediff2)
    times3.append(datetime.fromtimestamp(time.mktime(t)))
    lasteventtime = t
    firstLine = False

# add last case
lines.append(line)
timeseqs.append(times)
timeseqs2.append(times2)
timeseqs3.append(times3)
numlines+=1

# %%
numlines, len(lines), len(timeseqs), len(timeseqs2), len(timeseqs3)
# Out:
# (3805, 3804, 3804, 3804, 3804)

# %%
len(timeseqs3[1])
# Out:
# 3

# %%
timeseqs3
# Out:
# [[datetime.datetime(2012, 4, 3, 16, 55, 38),
#   datetime.datetime(2012, 4, 3, 16, 55, 53),
#   datetime.datetime(2012, 4, 5, 17, 15, 52)],
#  [datetime.datetime(2010, 10, 29, 18, 14, 6),
#   datetime.datetime(2010, 11, 4, 1, 16, 11),
#   datetime.datetime(2010, 11, 4, 1, 21, 17)],
#  [datetime.datetime(2010, 12, 15, 23, 31, 53),
#   datetime.datetime(2010, 12, 16, 17, 1, 7),
#   datetime.datetime(2010, 12, 16, 17, 8, 19)],
#  [datetime.datetime(2012, 4, 3, 21, 8, 32),
#   datetime.datetime(2012, 4, 3, 21, 45, 33),
#   datetime.datetime(2012, 4, 3, 21, 47, 22),
#   datetime.datetime(2012, 4, 3, 22, 15, 2),
#   datetime.datetime(2012, 4, 4, 0, 7, 28)],
#  [datetime.datetime(2011, 10, 25, 23, 13, 58),
#   datetime.datetime(2011, 10, 25, 23, 58, 55),
#   datetime.datetime(2011, 10, 26, 17, 54, 46)],
#  [datetime.datetime(2012, 7, 5, 16, 30, 32),
#   datetime.datetime(2012, 7, 5, 17, 25, 45),
#   datetime.datetime(2012, 7, 5, 17, 44, 46)],
#  [datetime.datetime(2010, 5, 7, 21, 2, 21),
#   datetime.datetime(2010, 5, 7, 21, 2, 34),
#   datetime.datetime(2010, 5, 24, 18, 26, 28),
#   datetime.datetime(2010, 5, 25, 23, 35, 44)],
#  [datetime.datetime(2010, 2, 10, 17, 50, 20),
#   datetime.datetime(2010, 3, 19, 17, 47, 6),
#   datetime.datetime(2010, 3, 19, 17, 47, 13)],
#  [datetime.datetime(2011, 12, 22, 0, 24, 41),
#   datetime.datetime(2011, 12, 22, 0, 25, 34),
#   datetime.datetime(2011, 12, 22, 18, 55, 43)],
#  [datetime.datetime(2011, 7, 5, 21, 47, 8),
#   datetime.datetime(2011, 7, 5, 21, 47, 22),
#   datetime.datetime(2011, 7, 5, 21, 52, 37)],
#  [datetime.datetime(2012, 2, 22, 23, 16, 52),
#   datetime.datetime(2012, 2, 23, 1, 14, 7),
#   datetime.datetime(2012, 2, 23, 1, 23, 57),
#   datetime.datetime(2012, 2, 23, 18, 47, 38)],
#  [datetime.datetime(2011, 10, 14, 15, 10, 47),
#   datetime.datetime(2011, 11, 3, 1, 17, 52),
#   datetime.datetime(2011, 11, 9, 22, 31, 37)],
#  [datetime.datetime(2010, 7, 7, 15, 54, 4),
#   datetime.datetime(2010, 7, 9, 18, 10, 52),
#   datetime.datetime(2010, 7, 9, 18, 11, 18)],
#  [datetime.datetime(2011, 1, 15, 0, 15, 21),
#   datetime.datetime(2011, 1, 27, 17, 6, 37),
#   datetime.datetime(2011, 1, 27, 19, 19, 15)],
#  [datetime.datetime(2012, 7, 23, 15, 49, 4),
#   datetime.datetime(2012, 7, 23, 15, 49, 14),
#   datetime.datetime(2012, 7, 23, 16, 51, 59),
#   datetime.datetime(2012, 8, 27, 18, 5, 23)],
#  [datetime.datetime(2010, 4, 27, 17, 49, 56),
#   datetime.datetime(2010, 6, 8, 19, 6, 56),
#   datetime.datetime(2010, 6, 8, 22, 46, 16)],
#  [datetime.datetime(2010, 12, 30, 18, 27, 17),
#   datetime.datetime(2010, 12, 30, 22, 14, 4),
#   datetime.datetime(2010, 12, 31, 0, 16, 35)],
#  [datetime.datetime(2011, 3, 31, 15, 28, 47),
#   datetime.datetime(2011, 3, 31, 15, 31, 59),
#   datetime.datetime(2011, 3, 31, 16, 39, 41),
#   datetime.datetime(2011, 3, 31, 19, 0, 28),
#   datetime.datetime(2011, 3, 31, 19, 0, 41)],
#  [datetime.datetime(2011, 11, 24, 23, 2, 16),
#   datetime.datetime(2011, 11, 24, 23, 2, 35),
#   datetime.datetime(2011, 12, 12, 18, 4, 47)],
#  [datetime.datetime(2012, 7, 30, 18, 7, 32),
#   datetime.datetime(2012, 7, 30, 18, 7, 40),
#   datetime.datetime(2012, 7, 30, 20, 29, 40)],
#  [datetime.datetime(2011, 1, 21, 18, 47, 20),
#   datetime.datetime(2011, 2, 7, 18, 19, 45),
#   datetime.datetime(2011, 2, 10, 18, 1, 20)],
#  [datetime.datetime(2011, 4, 27, 15, 38, 44),
#   datetime.datetime(2011, 4, 27, 20, 46, 13),
#   datetime.datetime(2011, 4, 28, 16, 18, 8)],
#  [datetime.datetime(2012, 1, 18, 17, 15, 30),
#   datetime.datetime(2012, 1, 18, 18, 46, 37)],
#  [datetime.datetime(2011, 6, 29, 18, 6, 48),
#   datetime.datetime(2011, 6, 30, 20, 58, 23),
#   datetime.datetime(2011, 7, 5, 15, 32, 43)],
#  [datetime.datetime(2011, 2, 10, 20, 13, 7),
#   datetime.datetime(2011, 2, 10, 20, 13, 33),
#   datetime.datetime(2011, 2, 11, 0, 20, 2),
#   datetime.datetime(2011, 3, 2, 22, 23, 58),
#   datetime.datetime(2011, 3, 2, 22, 24, 7),
#   datetime.datetime(2011, 3, 3, 0, 27, 52),
#   datetime.datetime(2011, 3, 4, 18, 37, 50),
#   datetime.datetime(2011, 3, 4, 18, 37, 55)],
#  [datetime.datetime(2012, 3, 20, 16, 57, 45),
#   datetime.datetime(2012, 3, 20, 16, 58, 15),
#   datetime.datetime(2012, 3, 20, 17, 18, 56)],
#  [datetime.datetime(2012, 8, 9, 20, 13, 3),
#   datetime.datetime(2012, 8, 9, 20, 13, 29),
#   datetime.datetime(2012, 8, 9, 20, 46)],
#  [datetime.datetime(2010, 12, 14, 19, 44, 26),
#   datetime.datetime(2010, 12, 14, 19, 44, 57),
#   datetime.datetime(2010, 12, 14, 19, 45, 12)],
#  [datetime.datetime(2011, 6, 16, 20, 23, 39),
#   datetime.datetime(2011, 6, 16, 20, 51, 5),
#   datetime.datetime(2011, 6, 16, 21, 39, 51)],
#  [datetime.datetime(2012, 4, 10, 16, 56, 32),
#   datetime.datetime(2012, 4, 10, 17, 27, 27),
#   datetime.datetime(2012, 4, 10, 18, 53, 28)],
#  [datetime.datetime(2010, 11, 30, 1, 9, 19),
#   datetime.datetime(2010, 11, 30, 1, 19, 59),
#   datetime.datetime(2010, 11, 30, 1, 20, 51)],
#  [datetime.datetime(2012, 1, 20, 23, 8, 14),
#   datetime.datetime(2012, 1, 25, 20, 46, 19),
#   datetime.datetime(2012, 3, 2, 19, 40, 59)],
#  [datetime.datetime(2011, 5, 25, 17, 48, 18),
#   datetime.datetime(2011, 5, 25, 17, 48, 43),
#   datetime.datetime(2011, 5, 30, 23, 4, 34)],
#  [datetime.datetime(2010, 12, 1, 22, 42, 59),
#   datetime.datetime(2010, 12, 2, 23, 7, 33),
#   datetime.datetime(2010, 12, 2, 23, 7, 41),
#   datetime.datetime(2010, 12, 2, 23, 8, 33)],
#  [datetime.datetime(2011, 11, 25, 23, 33, 54),
#   datetime.datetime(2011, 11, 25, 23, 47, 48),
#   datetime.datetime(2011, 11, 29, 23, 47, 35),
#   datetime.datetime(2011, 12, 3, 1, 25, 57)],
#  [datetime.datetime(2012, 1, 16, 19, 53, 1),
#   datetime.datetime(2012, 1, 16, 19, 59, 51),
#   datetime.datetime(2012, 1, 17, 1, 37, 54),
#   datetime.datetime(2012, 1, 17, 1, 37, 55)],
#  [datetime.datetime(2012, 6, 13, 21, 55, 36),
#   datetime.datetime(2012, 6, 14, 15, 7, 6),
#   datetime.datetime(2012, 6, 15, 15, 16, 27),
#   datetime.datetime(2012, 7, 2, 17, 41, 4)],
#  [datetime.datetime(2012, 7, 26, 23, 18, 26),
#   datetime.datetime(2012, 7, 26, 23, 18, 35),
#   datetime.datetime(2012, 7, 27, 18, 46, 28)],
#  [datetime.datetime(2010, 10, 14, 21, 53, 13),
#   datetime.datetime(2010, 10, 15, 21, 2, 36),
#   datetime.datetime(2010, 10, 28, 23, 12, 55),
#   datetime.datetime(2010, 10, 28, 23, 12, 55),
#   datetime.datetime(2010, 10, 29, 21, 42, 1),
#   datetime.datetime(2010, 11, 4, 17, 48, 12)],
#  [datetime.datetime(2011, 10, 26, 23, 51, 42),
#   datetime.datetime(2011, 11, 1, 0, 19, 3),
#   datetime.datetime(2011, 11, 7, 17, 44, 52),
#   datetime.datetime(2011, 11, 21, 17, 21, 23)],
#  [datetime.datetime(2012, 1, 30, 20, 32, 58),
#   datetime.datetime(2012, 1, 30, 20, 33, 23)],
#  [datetime.datetime(2010, 10, 29, 17, 39, 23),
#   datetime.datetime(2010, 11, 2, 23, 56, 13),
#   datetime.datetime(2010, 11, 3, 0, 39, 5)],
#  [datetime.datetime(2012, 3, 28, 20, 28, 37),
#   datetime.datetime(2012, 3, 28, 20, 28, 47),
#   datetime.datetime(2012, 3, 28, 23, 32, 57),
#   datetime.datetime(2012, 3, 28, 23, 32, 57)],
#  [datetime.datetime(2011, 4, 6, 23, 35, 49),
#   datetime.datetime(2011, 4, 6, 23, 36, 4),
#   datetime.datetime(2011, 4, 7, 23, 41, 23),
#   datetime.datetime(2011, 4, 13, 16, 49, 14),
#   datetime.datetime(2011, 4, 13, 16, 49, 22)],
#  [datetime.datetime(2011, 9, 16, 15, 4, 39),
#   datetime.datetime(2011, 9, 16, 15, 18, 12),
#   datetime.datetime(2011, 9, 16, 23, 4, 46)],
#  [datetime.datetime(2012, 5, 28, 23, 16, 47),
#   datetime.datetime(2012, 5, 28, 23, 18, 27)],
#  [datetime.datetime(2011, 4, 14, 23, 54, 28),
#   datetime.datetime(2011, 4, 14, 23, 54, 46),
#   datetime.datetime(2011, 4, 15, 18, 41, 19),
#   datetime.datetime(2011, 4, 27, 18, 30, 4),
#   datetime.datetime(2011, 4, 27, 18, 30, 13),
#   datetime.datetime(2011, 5, 6, 17, 42, 13),
#   datetime.datetime(2011, 5, 6, 17, 42, 28)],
#  [datetime.datetime(2012, 6, 26, 16, 46, 53),
#   datetime.datetime(2012, 6, 26, 16, 47, 39),
#   datetime.datetime(2012, 6, 26, 21, 5, 58)],
#  [datetime.datetime(2010, 12, 31, 0, 3, 15),
#   datetime.datetime(2011, 1, 11, 17, 40, 8),
#   datetime.datetime(2011, 1, 13, 20, 45, 18)],
#  [datetime.datetime(2012, 4, 11, 22, 9, 22),
#   datetime.datetime(2012, 4, 11, 22, 9, 45),
#   datetime.datetime(2012, 4, 12, 18, 31, 37)],
#  [datetime.datetime(2011, 6, 7, 15, 34, 53),
#   datetime.datetime(2011, 6, 7, 15, 35, 14),
#   datetime.datetime(2011, 7, 8, 16, 44, 58),
#   datetime.datetime(2011, 7, 12, 15, 0, 36)],
#  [datetime.datetime(2011, 11, 2, 17, 20, 14),
#   datetime.datetime(2011, 11, 2, 17, 20, 41),
#   datetime.datetime(2011, 11, 2, 18, 49, 41)],
#  [datetime.datetime(2011, 1, 25, 22, 15, 31),
#   datetime.datetime(2011, 1, 25, 22, 15, 58),
#   datetime.datetime(2011, 2, 14, 20, 48, 42)],
#  [datetime.datetime(2012, 7, 31, 19, 1, 15),
#   datetime.datetime(2012, 7, 31, 19, 2, 2)],
#  [datetime.datetime(2012, 2, 10, 20, 42, 26)],
#  [datetime.datetime(2010, 3, 12, 0, 15, 54),
#   datetime.datetime(2010, 4, 23, 15, 44, 51),
#   datetime.datetime(2010, 4, 23, 15, 44, 59),
#   datetime.datetime(2010, 4, 23, 15, 45, 4)],
#  [datetime.datetime(2012, 1, 11, 0, 1, 36),
#   datetime.datetime(2012, 1, 11, 0, 58, 8)],
#  [datetime.datetime(2011, 11, 8, 18, 18, 10),
#   datetime.datetime(2011, 11, 8, 18, 22, 35),
#   datetime.datetime(2011, 12, 6, 1, 33, 12)],
#  [datetime.datetime(2012, 8, 2, 17, 22, 58),
#   datetime.datetime(2012, 8, 3, 20, 12, 15),
#   datetime.datetime(2012, 8, 10, 18, 13, 48)],
#  [datetime.datetime(2010, 2, 9, 17, 31, 47),
#   datetime.datetime(2010, 2, 9, 17, 35, 12),
#   datetime.datetime(2010, 2, 9, 17, 35, 26),
#   datetime.datetime(2010, 2, 9, 17, 36, 27),
#   datetime.datetime(2010, 2, 19, 17, 31, 40),
#   datetime.datetime(2010, 2, 19, 17, 32)],
#  [datetime.datetime(2010, 12, 10, 18, 15, 54),
#   datetime.datetime(2010, 12, 10, 18, 16, 17),
#   datetime.datetime(2010, 12, 10, 18, 16, 34)],
#  [datetime.datetime(2011, 2, 25, 2, 1, 50),
#   datetime.datetime(2011, 2, 25, 2, 3, 45),
#   datetime.datetime(2011, 3, 4, 19, 2, 13)],
#  [datetime.datetime(2012, 6, 13, 0, 12, 48),
#   datetime.datetime(2012, 6, 15, 15, 27, 33),
#   datetime.datetime(2012, 6, 15, 18, 0, 52),
#   datetime.datetime(2012, 6, 18, 17, 42, 2)],
#  [datetime.datetime(2011, 11, 14, 23, 35, 55),
#   datetime.datetime(2011, 11, 18, 1, 58, 30),
#   datetime.datetime(2011, 11, 18, 1, 59, 3),
#   datetime.datetime(2011, 11, 25, 18, 30, 7),
#   datetime.datetime(2011, 11, 28, 22, 50, 35),
#   datetime.datetime(2011, 11, 28, 22, 59),
#   datetime.datetime(2011, 12, 7, 22, 41, 18)],
#  [datetime.datetime(2010, 9, 24, 15, 57, 49),
#   datetime.datetime(2010, 9, 24, 21, 43, 51),
#   datetime.datetime(2010, 9, 24, 21, 44, 52),
#   datetime.datetime(2010, 10, 4, 18, 48, 54),
#   datetime.datetime(2010, 10, 4, 18, 49, 8)],
#  [datetime.datetime(2010, 3, 16, 16, 59, 3),
#   datetime.datetime(2010, 3, 17, 18, 2, 3),
#   datetime.datetime(2010, 3, 17, 18, 49, 51)],
#  [datetime.datetime(2011, 5, 24, 20, 51, 35),
#   datetime.datetime(2011, 5, 24, 20, 52, 7),
#   datetime.datetime(2011, 5, 24, 21, 36, 11)],
#  [datetime.datetime(2010, 3, 9, 19, 9, 33),
#   datetime.datetime(2010, 3, 9, 19, 9, 44),
#   datetime.datetime(2010, 3, 18, 18, 27, 56)],
#  [datetime.datetime(2012, 7, 25, 15, 2, 54),
#   datetime.datetime(2012, 7, 30, 17, 39, 4),
#   datetime.datetime(2012, 8, 2, 23, 14, 7)],
#  [datetime.datetime(2012, 2, 8, 17, 33, 56),
#   datetime.datetime(2012, 2, 8, 17, 34, 8),
#   datetime.datetime(2012, 2, 8, 17, 34, 34)],
#  [datetime.datetime(2011, 9, 26, 18, 27, 14),
#   datetime.datetime(2011, 9, 29, 21, 54, 32),
#   datetime.datetime(2011, 9, 30, 17, 9, 23)],
#  [datetime.datetime(2012, 2, 28, 1, 31, 32),
#   datetime.datetime(2012, 2, 28, 17, 52, 59),
#   datetime.datetime(2012, 2, 29, 17, 25, 13),
#   datetime.datetime(2012, 2, 29, 17, 25, 14)],
#  [datetime.datetime(2012, 7, 5, 20, 16, 51),
#   datetime.datetime(2012, 7, 5, 20, 20, 39),
#   datetime.datetime(2012, 7, 9, 21, 21, 24)],
#  [datetime.datetime(2011, 5, 11, 18, 16, 32),
#   datetime.datetime(2011, 5, 11, 18, 17, 55),
#   datetime.datetime(2011, 5, 16, 16, 33, 29)],
#  [datetime.datetime(2010, 6, 18, 21, 47, 15),
#   datetime.datetime(2010, 6, 18, 22, 18, 15),
#   datetime.datetime(2010, 6, 29, 15, 35, 47),
#   datetime.datetime(2010, 6, 29, 16, 33, 7)],
#  [datetime.datetime(2012, 1, 30, 18, 9, 29),
#   datetime.datetime(2012, 1, 30, 18, 9, 57),
#   datetime.datetime(2012, 1, 31, 17, 12, 6)],
#  [datetime.datetime(2010, 6, 7, 15, 30, 54),
#   datetime.datetime(2010, 6, 7, 15, 49, 10),
#   datetime.datetime(2010, 6, 7, 23, 16, 44),
#   datetime.datetime(2010, 6, 8, 18, 37, 29),
#   datetime.datetime(2010, 6, 9, 15, 18, 5),
#   datetime.datetime(2010, 6, 9, 15, 18, 28),
#   datetime.datetime(2010, 6, 16, 17, 23, 7)],
#  [datetime.datetime(2011, 1, 27, 17, 34, 59),
#   datetime.datetime(2011, 1, 27, 18, 32, 40),
#   datetime.datetime(2011, 1, 27, 18, 34, 24)],
#  [datetime.datetime(2011, 1, 12, 20, 28, 16),
#   datetime.datetime(2011, 1, 24, 18, 21, 26),
#   datetime.datetime(2011, 1, 26, 17, 12, 39)],
#  [datetime.datetime(2010, 9, 24, 23, 35, 31),
#   datetime.datetime(2010, 9, 27, 17, 11, 48),
#   datetime.datetime(2010, 9, 28, 16, 31, 41),
#   datetime.datetime(2010, 11, 8, 18, 33, 36),
#   datetime.datetime(2010, 11, 8, 18, 33, 57)],
#  [datetime.datetime(2010, 12, 16, 18, 33, 24),
#   datetime.datetime(2010, 12, 16, 18, 40, 25),
#   datetime.datetime(2010, 12, 17, 0, 52, 50)],
#  [datetime.datetime(2010, 6, 29, 22, 0, 48),
#   datetime.datetime(2010, 6, 29, 23, 16, 26),
#   datetime.datetime(2010, 6, 30, 16, 5, 4),
#   datetime.datetime(2010, 6, 30, 22, 19),
#   datetime.datetime(2010, 7, 1, 17, 0, 3),
#   datetime.datetime(2010, 7, 2, 22, 7, 18),
#   datetime.datetime(2010, 7, 2, 22, 8, 52)],
#  [datetime.datetime(2011, 10, 6, 15, 50, 55),
#   datetime.datetime(2011, 10, 7, 22, 3, 47),
#   datetime.datetime(2011, 10, 14, 22, 44, 32)],
#  [datetime.datetime(2010, 5, 6, 23, 51, 48),
#   datetime.datetime(2010, 5, 24, 18, 23, 15),
#   datetime.datetime(2010, 5, 25, 21, 48, 24),
#   datetime.datetime(2010, 5, 25, 22, 11, 28)],
#  [datetime.datetime(2011, 4, 8, 21, 2, 3),
#   datetime.datetime(2011, 4, 8, 21, 2, 38),
#   datetime.datetime(2011, 4, 8, 21, 7, 10)],
#  [datetime.datetime(2012, 7, 19, 18, 59, 25),
#   datetime.datetime(2012, 7, 20, 16, 49, 34),
#   datetime.datetime(2012, 7, 20, 22, 44, 15)],
#  [datetime.datetime(2011, 3, 7, 20, 2, 24),
#   datetime.datetime(2011, 3, 7, 20, 2, 41),
#   datetime.datetime(2011, 3, 7, 22, 14, 21)],
#  [datetime.datetime(2011, 12, 5, 23, 22, 17),
#   datetime.datetime(2011, 12, 5, 23, 58, 56),
#   datetime.datetime(2011, 12, 13, 18, 22, 4)],
#  [datetime.datetime(2012, 4, 24, 22, 7, 3),
#   datetime.datetime(2012, 5, 8, 18, 53, 6),
#   datetime.datetime(2012, 5, 8, 20, 31, 30),
#   datetime.datetime(2012, 5, 8, 22, 4, 27)],
#  [datetime.datetime(2011, 2, 9, 22, 28, 58),
#   datetime.datetime(2011, 2, 9, 23, 21, 2),
#   datetime.datetime(2011, 2, 9, 23, 21, 46)],
#  [datetime.datetime(2011, 2, 15, 0, 23, 8),
#   datetime.datetime(2011, 2, 15, 20, 17, 46),
#   datetime.datetime(2011, 2, 15, 20, 52, 47)],
#  [datetime.datetime(2011, 5, 6, 15, 33, 7),
#   datetime.datetime(2011, 5, 6, 15, 33, 39),
#   datetime.datetime(2011, 5, 6, 20, 55, 50),
#   datetime.datetime(2011, 5, 12, 21, 45, 43),
#   datetime.datetime(2011, 5, 12, 21, 45, 54)],
#  [datetime.datetime(2012, 6, 7, 23, 31, 32),
#   datetime.datetime(2012, 6, 8, 14, 47, 21),
#   datetime.datetime(2012, 6, 8, 14, 47, 30)],
#  [datetime.datetime(2010, 8, 19, 17, 48, 49),
#   datetime.datetime(2010, 8, 19, 17, 49, 49),
#   datetime.datetime(2010, 8, 19, 18, 7, 15),
#   datetime.datetime(2010, 9, 13, 16, 15, 21),
#   datetime.datetime(2010, 9, 13, 16, 49, 39)],
#  [datetime.datetime(2012, 7, 25, 23, 34, 31),
#   datetime.datetime(2012, 8, 27, 21, 28, 50),
#   datetime.datetime(2012, 8, 27, 22, 18, 5)],
#  [datetime.datetime(2010, 3, 12, 18, 28, 49),
#   datetime.datetime(2010, 3, 12, 18, 29),
#   datetime.datetime(2010, 3, 12, 18, 37, 27)],
#  [datetime.datetime(2011, 11, 28, 17, 10, 27),
#   datetime.datetime(2011, 11, 28, 18, 46, 59),
#   datetime.datetime(2011, 11, 28, 18, 46, 59)],
#  [datetime.datetime(2010, 4, 8, 16, 58, 3),
#   datetime.datetime(2010, 4, 8, 17, 1, 5),
#   datetime.datetime(2010, 4, 8, 17, 1, 11),
#   datetime.datetime(2010, 4, 8, 17, 1, 19)],
#  [datetime.datetime(2012, 6, 21, 20, 50, 46),
#   datetime.datetime(2012, 6, 21, 21, 30, 2),
#   datetime.datetime(2012, 6, 21, 22, 32, 8),
#   datetime.datetime(2012, 6, 25, 20, 3, 33)],
#  [datetime.datetime(2011, 1, 26, 20, 24, 58),
#   datetime.datetime(2011, 1, 26, 20, 59, 56),
#   datetime.datetime(2011, 1, 26, 21, 0, 3),
#   datetime.datetime(2011, 1, 28, 23, 29, 17)],
#  [datetime.datetime(2011, 4, 19, 22, 42, 45),
#   datetime.datetime(2011, 4, 19, 22, 45, 25),
#   datetime.datetime(2011, 4, 19, 22, 45, 42)],
#  [datetime.datetime(2011, 2, 8, 20, 57, 41),
#   datetime.datetime(2011, 2, 8, 20, 58, 1),
#   datetime.datetime(2011, 2, 10, 17, 27, 30),
#   datetime.datetime(2011, 2, 14, 21, 1, 11),
#   datetime.datetime(2011, 2, 14, 21, 2, 59),
#   datetime.datetime(2011, 3, 3, 18, 46, 37),
#   datetime.datetime(2011, 3, 3, 23, 5, 29)],
#  [datetime.datetime(2012, 6, 6, 22, 48, 56),
#   datetime.datetime(2012, 6, 7, 20, 19, 44),
#   datetime.datetime(2012, 6, 8, 15, 13, 29)],
#  [datetime.datetime(2011, 8, 5, 21, 0, 13),
#   datetime.datetime(2011, 8, 11, 18, 30, 47),
#   datetime.datetime(2011, 8, 12, 21, 42, 55),
#   datetime.datetime(2011, 8, 19, 20, 25, 37)],
#  [datetime.datetime(2012, 3, 2, 18, 13, 46),
#   datetime.datetime(2012, 3, 2, 18, 13, 56),
#   datetime.datetime(2012, 3, 2, 18, 34, 3)],
#  [datetime.datetime(2010, 4, 19, 15, 44, 31),
#   datetime.datetime(2010, 4, 19, 17, 15, 20),
#   datetime.datetime(2010, 4, 19, 17, 26, 5)],
#  [datetime.datetime(2011, 1, 12, 19, 39, 32),
#   datetime.datetime(2011, 1, 12, 19, 39, 56),
#   datetime.datetime(2011, 1, 12, 19, 50, 26),
#   datetime.datetime(2011, 1, 12, 20, 7, 51),
#   datetime.datetime(2011, 1, 12, 20, 34, 34),
#   datetime.datetime(2011, 1, 26, 18, 25, 14),
#   datetime.datetime(2011, 1, 26, 18, 26, 4)],
#  [datetime.datetime(2012, 3, 7, 20, 0, 5),
#   datetime.datetime(2012, 3, 8, 22, 53, 36),
#   datetime.datetime(2012, 3, 9, 23, 48, 25)],
#  [datetime.datetime(2010, 10, 5, 22, 55, 27),
#   datetime.datetime(2010, 10, 5, 23, 9, 10),
#   datetime.datetime(2010, 10, 5, 23, 9, 39)],
#  [datetime.datetime(2012, 1, 9, 20, 19, 35),
#   datetime.datetime(2012, 1, 10, 1, 14, 26),
#   datetime.datetime(2012, 1, 10, 1, 14, 53),
#   datetime.datetime(2012, 1, 10, 1, 14, 53)],
#  [datetime.datetime(2011, 2, 9, 23, 35, 27),
#   datetime.datetime(2011, 2, 10, 0, 16, 21),
#   datetime.datetime(2011, 2, 10, 0, 24, 44)],
#  [datetime.datetime(2011, 5, 18, 16, 39, 41),
#   datetime.datetime(2011, 5, 18, 16, 39, 49),
#   datetime.datetime(2011, 5, 18, 16, 41, 36),
#   datetime.datetime(2011, 5, 23, 23, 20, 54),
#   datetime.datetime(2011, 5, 26, 15, 55, 33),
#   datetime.datetime(2011, 5, 26, 15, 56)],
#  [datetime.datetime(2010, 2, 10, 19, 25, 33),
#   datetime.datetime(2010, 2, 10, 19, 33, 38),
#   datetime.datetime(2010, 2, 10, 19, 33, 49)],
#  [datetime.datetime(2012, 5, 18, 20, 8, 58),
#   datetime.datetime(2012, 5, 24, 18, 0, 37),
#   datetime.datetime(2012, 5, 25, 16, 12, 16)],
#  [datetime.datetime(2012, 7, 2, 15, 35, 6),
#   datetime.datetime(2012, 7, 2, 19, 0, 33),
#   datetime.datetime(2012, 7, 2, 19, 1, 29)],
#  [datetime.datetime(2010, 12, 15, 1, 19, 51),
#   datetime.datetime(2010, 12, 17, 19, 45, 21),
#   datetime.datetime(2010, 12, 24, 0, 26, 7),
#   datetime.datetime(2011, 1, 18, 20, 15, 13),
#   datetime.datetime(2011, 1, 18, 20, 15, 29)],
#  [datetime.datetime(2011, 5, 24, 15, 13, 23),
#   datetime.datetime(2011, 5, 31, 23, 42, 9),
#   datetime.datetime(2011, 6, 6, 18, 19, 1)],
#  [datetime.datetime(2010, 9, 20, 23, 57, 1),
#   datetime.datetime(2010, 9, 21, 15, 45, 37),
#   datetime.datetime(2010, 9, 21, 15, 53, 48)],
#  [datetime.datetime(2011, 9, 21, 15, 12, 16),
#   datetime.datetime(2011, 9, 21, 15, 46, 44),
#   datetime.datetime(2011, 9, 27, 21, 20, 30)],
#  [datetime.datetime(2011, 2, 25, 19, 55, 2),
#   datetime.datetime(2011, 2, 25, 22, 26, 45),
#   datetime.datetime(2011, 2, 25, 22, 28, 30)],
#  [datetime.datetime(2010, 8, 10, 15, 16, 9),
#   datetime.datetime(2010, 8, 12, 18, 33, 35),
#   datetime.datetime(2010, 8, 13, 15, 24, 41)],
#  [datetime.datetime(2011, 10, 4, 23, 47, 43),
#   datetime.datetime(2011, 10, 7, 21, 29, 10),
#   datetime.datetime(2011, 10, 7, 21, 30)],
#  [datetime.datetime(2010, 10, 15, 16, 27, 20),
#   datetime.datetime(2010, 10, 27, 19, 46, 30),
#   datetime.datetime(2010, 10, 27, 19, 46, 36)],
#  [datetime.datetime(2010, 9, 28, 20, 44, 1),
#   datetime.datetime(2010, 9, 28, 20, 46, 50),
#   datetime.datetime(2010, 9, 28, 22, 3, 8)],
#  [datetime.datetime(2012, 1, 14, 1, 36, 23),
#   datetime.datetime(2012, 1, 14, 1, 36, 49)],
#  [datetime.datetime(2010, 2, 11, 17, 48, 50),
#   datetime.datetime(2010, 2, 24, 1, 56, 28),
#   datetime.datetime(2010, 2, 24, 1, 56, 36)],
#  [datetime.datetime(2011, 11, 23, 23, 43, 38),
#   datetime.datetime(2011, 11, 25, 19, 12, 19),
#   datetime.datetime(2011, 11, 25, 23, 1, 18),
#   datetime.datetime(2011, 11, 28, 18, 25),
#   datetime.datetime(2011, 11, 28, 18, 25, 2)],
#  [datetime.datetime(2012, 1, 9, 19, 1, 47),
#   datetime.datetime(2012, 1, 9, 20, 20, 28),
#   datetime.datetime(2012, 1, 9, 20, 21, 29)],
#  [datetime.datetime(2012, 5, 2, 23, 54, 51),
#   datetime.datetime(2012, 5, 3, 15, 51, 9),
#   datetime.datetime(2012, 5, 3, 16, 1, 21),
#   datetime.datetime(2012, 5, 17, 15, 46, 38),
#   datetime.datetime(2012, 5, 17, 15, 47, 13),
#   datetime.datetime(2012, 5, 18, 15, 18, 57)],
#  [datetime.datetime(2011, 8, 29, 22, 12, 48),
#   datetime.datetime(2011, 8, 30, 17, 49, 49),
#   datetime.datetime(2011, 8, 30, 18, 6, 35),
#   datetime.datetime(2011, 8, 31, 15, 34, 45)],
#  [datetime.datetime(2010, 9, 17, 0, 2, 20),
#   datetime.datetime(2010, 9, 21, 22, 3, 12),
#   datetime.datetime(2010, 9, 27, 18, 8, 54)],
#  [datetime.datetime(2010, 11, 15, 18, 15, 12),
#   datetime.datetime(2010, 11, 15, 18, 15, 27),
#   datetime.datetime(2010, 11, 16, 21, 58, 1),
#   datetime.datetime(2010, 11, 16, 22, 1, 14)],
#  [datetime.datetime(2011, 10, 24, 18, 22, 28),
#   datetime.datetime(2011, 11, 4, 0, 48, 18),
#   datetime.datetime(2011, 11, 5, 1, 24, 35),
#   datetime.datetime(2011, 11, 9, 23, 20, 52)],
#  [datetime.datetime(2010, 10, 5, 15, 46, 59),
#   datetime.datetime(2010, 10, 5, 15, 59, 41),
#   datetime.datetime(2010, 10, 5, 16, 0, 18)],
#  [datetime.datetime(2012, 7, 17, 18, 44, 26),
#   datetime.datetime(2012, 7, 17, 18, 44, 48),
#   datetime.datetime(2012, 7, 18, 21, 11, 34)],
#  [datetime.datetime(2012, 1, 18, 17, 12, 4),
#   datetime.datetime(2012, 1, 18, 17, 21, 52),
#   datetime.datetime(2012, 1, 18, 18, 42, 3)],
#  [datetime.datetime(2012, 2, 22, 23, 49, 43),
#   datetime.datetime(2012, 2, 22, 23, 49, 52),
#   datetime.datetime(2012, 2, 29, 18, 36, 49)],
#  [datetime.datetime(2012, 4, 11, 21, 30, 7),
#   datetime.datetime(2012, 4, 12, 17, 29, 39),
#   datetime.datetime(2012, 4, 12, 20, 57, 39)],
#  [datetime.datetime(2011, 10, 6, 18, 23, 22),
#   datetime.datetime(2011, 10, 6, 22, 7, 44),
#   datetime.datetime(2011, 10, 6, 22, 31, 30)],
#  [datetime.datetime(2011, 9, 29, 17, 51, 55),
#   datetime.datetime(2011, 9, 30, 21, 14, 19)],
#  [datetime.datetime(2010, 5, 20, 16, 31, 32),
#   datetime.datetime(2010, 5, 24, 18, 55, 17),
#   datetime.datetime(2010, 5, 24, 18, 59, 57)],
#  [datetime.datetime(2010, 5, 19, 23, 8, 49),
#   datetime.datetime(2010, 5, 20, 15, 53, 47),
#   datetime.datetime(2010, 5, 24, 15, 15, 57),
#   datetime.datetime(2010, 5, 24, 15, 18, 9)],
#  [datetime.datetime(2010, 11, 2, 22, 49, 59),
#   datetime.datetime(2010, 11, 3, 23, 6, 18),
#   datetime.datetime(2010, 11, 3, 23, 6, 51),
#   datetime.datetime(2010, 11, 18, 18, 52, 12),
#   datetime.datetime(2010, 11, 18, 18, 52, 18)],
#  [datetime.datetime(2012, 7, 13, 16, 20),
#   datetime.datetime(2012, 7, 13, 21, 25, 40),
#   datetime.datetime(2012, 7, 13, 21, 48, 10),
#   datetime.datetime(2012, 7, 18, 15, 5, 36)],
#  [datetime.datetime(2010, 10, 25, 21, 14, 8),
#   datetime.datetime(2010, 10, 27, 21, 27, 14),
#   datetime.datetime(2010, 10, 27, 21, 29, 30)],
#  [datetime.datetime(2012, 1, 9, 22, 58, 58),
#   datetime.datetime(2012, 1, 9, 22, 59, 9),
#   datetime.datetime(2012, 1, 10, 18, 3, 1)],
#  [datetime.datetime(2010, 2, 2, 22, 49, 13),
#   datetime.datetime(2010, 2, 2, 23, 4, 15),
#   datetime.datetime(2010, 2, 3, 23, 27, 7),
#   datetime.datetime(2010, 2, 3, 23, 27, 16)],
#  [datetime.datetime(2011, 2, 22, 0, 36, 25),
#   datetime.datetime(2011, 2, 22, 1, 44, 27),
#   datetime.datetime(2011, 3, 3, 23, 26, 19)],
#  [datetime.datetime(2012, 2, 8, 20, 28, 3),
#   datetime.datetime(2012, 2, 10, 19, 28, 30),
#   datetime.datetime(2012, 3, 5, 20, 31, 8)],
#  [datetime.datetime(2010, 9, 21, 18, 53),
#   datetime.datetime(2010, 9, 23, 17, 25, 7),
#   datetime.datetime(2010, 9, 27, 18, 9, 43),
#   datetime.datetime(2010, 9, 29, 15, 6, 22),
#   datetime.datetime(2010, 9, 29, 16, 4, 55),
#   datetime.datetime(2010, 9, 29, 20, 29, 35),
#   datetime.datetime(2010, 9, 29, 20, 29, 47)],
#  [datetime.datetime(2011, 11, 16, 19, 45, 30),
#   datetime.datetime(2011, 11, 17, 22, 31, 33),
#   datetime.datetime(2011, 11, 17, 22, 32, 9)],
#  [datetime.datetime(2012, 6, 1, 16, 18, 57),
#   datetime.datetime(2012, 6, 4, 15, 56, 22),
#   datetime.datetime(2012, 6, 4, 17, 46, 33),
#   datetime.datetime(2012, 6, 4, 17, 46, 33)],
#  [datetime.datetime(2011, 4, 28, 21, 46, 15),
#   datetime.datetime(2011, 4, 28, 21, 46, 46),
#   datetime.datetime(2011, 5, 9, 23, 43, 48)],
#  [datetime.datetime(2011, 12, 14, 0, 45, 50),
#   datetime.datetime(2011, 12, 14, 19, 27, 28)],
#  [datetime.datetime(2012, 4, 12, 22, 59, 24),
#   datetime.datetime(2012, 4, 13, 23, 7, 2),
#   datetime.datetime(2012, 4, 16, 21, 40, 1)],
#  [datetime.datetime(2011, 8, 22, 15, 6, 31),
#   datetime.datetime(2011, 8, 22, 17, 14, 28),
#   datetime.datetime(2011, 8, 22, 17, 31, 48)],
#  [datetime.datetime(2010, 6, 11, 18, 18, 2),
#   datetime.datetime(2010, 6, 11, 20, 22, 40),
#   datetime.datetime(2010, 6, 16, 16, 4, 16)],
#  [datetime.datetime(2011, 11, 1, 0, 30, 39),
#   datetime.datetime(2011, 11, 1, 0, 30, 50),
#   datetime.datetime(2011, 11, 2, 22, 41, 11)],
#  [datetime.datetime(2010, 12, 7, 20, 10, 52),
#   datetime.datetime(2010, 12, 9, 20, 19, 43),
#   datetime.datetime(2010, 12, 20, 23, 24, 30),
#   datetime.datetime(2010, 12, 21, 22, 36, 16),
#   datetime.datetime(2010, 12, 21, 23, 31, 29)],
#  [datetime.datetime(2011, 3, 4, 19, 26, 28),
#   datetime.datetime(2011, 3, 4, 19, 29, 32),
#   datetime.datetime(2011, 3, 4, 20, 32, 51),
#   datetime.datetime(2011, 3, 11, 20, 48, 16),
#   datetime.datetime(2011, 3, 11, 20, 48, 28)],
#  [datetime.datetime(2011, 6, 21, 21, 40, 37),
#   datetime.datetime(2011, 6, 23, 21, 54, 10),
#   datetime.datetime(2011, 7, 11, 15, 42, 6)],
#  [datetime.datetime(2010, 10, 12, 18, 50, 55),
#   datetime.datetime(2010, 10, 12, 20, 58, 7),
#   datetime.datetime(2010, 10, 12, 23, 5, 33)],
#  [datetime.datetime(2012, 1, 11, 19, 39, 43),
#   datetime.datetime(2012, 1, 11, 19, 40, 6),
#   datetime.datetime(2012, 1, 11, 19, 41, 58)],
#  [datetime.datetime(2012, 8, 2, 18, 2, 57),
#   datetime.datetime(2012, 8, 3, 20, 56, 13)],
#  [datetime.datetime(2012, 5, 14, 20, 39, 34),
#   datetime.datetime(2012, 5, 14, 20, 39, 41),
#   datetime.datetime(2012, 5, 14, 21, 28, 38)],
#  [datetime.datetime(2011, 7, 19, 18, 43, 29),
#   datetime.datetime(2011, 7, 27, 16, 19, 8)],
#  [datetime.datetime(2011, 1, 26, 17, 16, 35),
#   datetime.datetime(2011, 1, 26, 17, 57, 2),
#   datetime.datetime(2011, 1, 26, 17, 57, 35),
#   datetime.datetime(2011, 1, 27, 17, 24, 33)],
#  [datetime.datetime(2010, 4, 15, 15, 13, 46),
#   datetime.datetime(2010, 4, 27, 22, 30, 12),
#   datetime.datetime(2010, 4, 27, 22, 30, 18)],
#  [datetime.datetime(2010, 3, 24, 20, 14, 7),
#   datetime.datetime(2010, 3, 24, 20, 14, 29),
#   datetime.datetime(2010, 3, 24, 20, 14, 37),
#   datetime.datetime(2010, 3, 24, 20, 14, 41)],
#  [datetime.datetime(2011, 3, 4, 18, 34, 36),
#   datetime.datetime(2011, 3, 4, 18, 35, 5),
#   datetime.datetime(2011, 3, 9, 0, 20, 32)],
#  [datetime.datetime(2011, 3, 26, 1, 16),
#   datetime.datetime(2011, 3, 26, 1, 17, 36),
#   datetime.datetime(2011, 3, 26, 1, 31, 47),
#   datetime.datetime(2011, 3, 28, 17, 2, 16),
#   datetime.datetime(2011, 3, 31, 23, 35, 15),
#   datetime.datetime(2011, 4, 8, 20, 49, 14),
#   datetime.datetime(2011, 4, 8, 21, 1, 12)],
#  [datetime.datetime(2011, 11, 11, 19, 10, 51),
#   datetime.datetime(2011, 11, 11, 19, 52, 25),
#   datetime.datetime(2011, 11, 15, 17, 46, 26),
#   datetime.datetime(2011, 11, 15, 17, 47, 32),
#   datetime.datetime(2011, 11, 15, 17, 47, 33)],
#  [datetime.datetime(2011, 7, 25, 19, 3, 37),
#   datetime.datetime(2011, 7, 28, 21, 41, 4),
#   datetime.datetime(2011, 8, 4, 17, 47, 48),
#   datetime.datetime(2011, 8, 4, 21, 25, 57)],
#  [datetime.datetime(2011, 11, 23, 19, 46, 1),
#   datetime.datetime(2011, 11, 26, 0, 11, 6),
#   datetime.datetime(2011, 11, 28, 20, 46, 18)],
#  [datetime.datetime(2012, 2, 1, 20, 34, 3),
#   datetime.datetime(2012, 2, 1, 20, 35, 16)],
#  [datetime.datetime(2012, 3, 15, 22, 28, 2),
#   datetime.datetime(2012, 3, 16, 20, 30, 26),
#   datetime.datetime(2012, 3, 17, 0, 29, 1),
#   datetime.datetime(2012, 3, 17, 0, 29, 2)],
#  [datetime.datetime(2012, 5, 28, 22, 20, 59),
#   datetime.datetime(2012, 5, 28, 22, 21, 21),
#   datetime.datetime(2012, 5, 28, 22, 41, 6),
#   datetime.datetime(2012, 5, 29, 16, 6, 3)],
#  [datetime.datetime(2011, 7, 21, 21, 48, 19),
#   datetime.datetime(2011, 7, 22, 21, 5, 46)],
#  [datetime.datetime(2011, 4, 12, 0, 1, 34),
#   datetime.datetime(2011, 4, 12, 0, 1, 52),
#   datetime.datetime(2011, 4, 13, 18, 20, 49)],
#  [datetime.datetime(2011, 5, 17, 17, 14, 34),
#   datetime.datetime(2011, 5, 17, 17, 14, 52),
#   datetime.datetime(2011, 5, 20, 20, 41, 53)],
#  [datetime.datetime(2010, 9, 22, 23, 39, 16),
#   datetime.datetime(2010, 9, 23, 16, 37, 42),
#   datetime.datetime(2010, 9, 23, 16, 38, 14)],
#  [datetime.datetime(2011, 11, 23, 18, 44, 28),
#   datetime.datetime(2011, 11, 23, 20, 21, 30)],
#  [datetime.datetime(2010, 10, 19, 22, 8, 14),
#   datetime.datetime(2010, 10, 21, 0, 3, 58),
#   datetime.datetime(2010, 10, 21, 0, 4, 16),
#   datetime.datetime(2010, 10, 21, 16, 26, 29)],
#  [datetime.datetime(2010, 6, 23, 23, 57, 59),
#   datetime.datetime(2010, 6, 28, 20, 12, 55),
#   datetime.datetime(2010, 7, 7, 18, 10, 15),
#   datetime.datetime(2010, 7, 7, 18, 10, 30)],
#  [datetime.datetime(2011, 1, 19, 19, 8, 18),
#   datetime.datetime(2011, 2, 5, 1, 33, 9),
#   datetime.datetime(2011, 2, 7, 19, 48, 8)],
#  [datetime.datetime(2010, 7, 23, 22, 27, 40),
#   datetime.datetime(2010, 7, 27, 15, 36, 36),
#   datetime.datetime(2010, 7, 27, 15, 37, 32)],
#  [datetime.datetime(2011, 7, 14, 21, 26, 36),
#   datetime.datetime(2011, 7, 14, 23, 50, 15),
#   datetime.datetime(2011, 8, 3, 16, 14)],
#  [datetime.datetime(2011, 7, 27, 23, 30, 16),
#   datetime.datetime(2011, 8, 2, 23, 54, 16),
#   datetime.datetime(2011, 8, 10, 20, 43, 40)],
#  [datetime.datetime(2012, 5, 17, 23, 53, 8),
#   datetime.datetime(2012, 5, 18, 14, 58, 20),
#   datetime.datetime(2012, 5, 21, 16, 27, 17)],
#  [datetime.datetime(2012, 8, 2, 17, 26, 4),
#   datetime.datetime(2012, 8, 22, 22, 24, 49),
#   datetime.datetime(2012, 8, 22, 22, 28, 26)],
#  [datetime.datetime(2012, 6, 20, 22, 41, 25),
#   datetime.datetime(2012, 6, 20, 22, 44, 2),
#   datetime.datetime(2012, 6, 20, 22, 44, 33)],
#  [datetime.datetime(2010, 11, 25, 2, 2, 59),
#   datetime.datetime(2010, 11, 25, 2, 21, 52),
#   datetime.datetime(2010, 11, 25, 2, 22)],
#  [datetime.datetime(2010, 4, 28, 23, 21, 11),
#   datetime.datetime(2010, 4, 29, 18, 15, 16),
#   datetime.datetime(2010, 5, 3, 20, 56, 35)],
#  [datetime.datetime(2010, 10, 27, 23, 21, 46),
#   datetime.datetime(2010, 11, 2, 23, 57, 9),
#   datetime.datetime(2010, 11, 2, 23, 57, 16),
#   datetime.datetime(2010, 11, 2, 23, 57, 22)],
#  [datetime.datetime(2012, 8, 10, 14, 59, 37),
#   datetime.datetime(2012, 8, 10, 15, 2, 47),
#   datetime.datetime(2012, 8, 10, 15, 18, 58)],
#  [datetime.datetime(2011, 11, 8, 22, 32, 15),
#   datetime.datetime(2011, 11, 9, 17, 39, 45),
#   datetime.datetime(2011, 11, 9, 17, 39, 46)],
#  [datetime.datetime(2011, 4, 20, 15, 34, 5),
#   datetime.datetime(2011, 4, 20, 15, 35, 25),
#   datetime.datetime(2011, 4, 27, 17, 53, 20)],
#  [datetime.datetime(2011, 2, 23, 2, 6, 59),
#   datetime.datetime(2011, 2, 23, 2, 7, 16),
#   datetime.datetime(2011, 2, 28, 19, 43, 36)],
#  [datetime.datetime(2012, 6, 26, 22, 50, 34),
#   datetime.datetime(2012, 7, 3, 15, 44, 6),
#   datetime.datetime(2012, 7, 6, 16, 50, 50)],
#  [datetime.datetime(2011, 1, 19, 23, 55, 14),
#   datetime.datetime(2011, 1, 19, 23, 55, 35),
#   datetime.datetime(2011, 1, 21, 0, 21, 38),
#   datetime.datetime(2011, 1, 24, 22, 38, 44),
#   datetime.datetime(2011, 2, 28, 18, 40, 26)],
#  [datetime.datetime(2010, 11, 23, 18, 55, 28),
#   datetime.datetime(2010, 11, 30, 23, 9, 41),
#   datetime.datetime(2010, 11, 30, 23, 10, 42)],
#  [datetime.datetime(2012, 3, 6, 17, 24, 19),
#   datetime.datetime(2012, 3, 6, 22, 39, 56),
#   datetime.datetime(2012, 3, 6, 23, 7, 30)],
#  [datetime.datetime(2011, 1, 12, 1, 41, 38),
#   datetime.datetime(2011, 1, 27, 19, 59, 56),
#   datetime.datetime(2011, 1, 27, 20, 0, 26)],
#  [datetime.datetime(2011, 1, 28, 20, 42, 47),
#   datetime.datetime(2011, 2, 9, 22, 50, 46),
#   datetime.datetime(2011, 2, 9, 22, 50, 56)],
#  [datetime.datetime(2010, 12, 2, 18, 21, 12),
#   datetime.datetime(2010, 12, 2, 19, 16, 17),
#   datetime.datetime(2010, 12, 2, 19, 16, 35),
#   datetime.datetime(2010, 12, 7, 1, 45, 40),
#   datetime.datetime(2010, 12, 7, 1, 45, 48)],
#  [datetime.datetime(2010, 3, 23, 17, 10, 15),
#   datetime.datetime(2010, 3, 24, 17, 39, 7),
#   datetime.datetime(2010, 3, 24, 17, 39, 20),
#   datetime.datetime(2010, 5, 6, 15, 36, 35)],
#  [datetime.datetime(2010, 10, 18, 21, 15, 6),
#   datetime.datetime(2010, 10, 18, 21, 29, 40),
#   datetime.datetime(2010, 10, 19, 18, 17, 6),
#   datetime.datetime(2010, 11, 15, 22, 47, 26)],
#  [datetime.datetime(2012, 7, 30, 18, 55, 26),
#   datetime.datetime(2012, 7, 30, 18, 55, 48),
#   datetime.datetime(2012, 7, 30, 21, 14, 37)],
#  [datetime.datetime(2011, 12, 29, 1, 51, 52),
#   datetime.datetime(2011, 12, 29, 19, 16, 43),
#   datetime.datetime(2011, 12, 30, 17, 1, 38)],
#  [datetime.datetime(2011, 3, 9, 22, 27, 13),
#   datetime.datetime(2011, 3, 11, 17, 5, 59),
#   datetime.datetime(2011, 3, 11, 17, 22, 38)],
#  [datetime.datetime(2012, 6, 18, 18, 49),
#   datetime.datetime(2012, 6, 20, 15, 11, 19),
#   datetime.datetime(2012, 6, 20, 15, 11, 20)],
#  [datetime.datetime(2011, 5, 5, 17, 41, 25),
#   datetime.datetime(2011, 5, 5, 17, 42, 8),
#   datetime.datetime(2011, 5, 5, 21, 14, 58)],
#  [datetime.datetime(2010, 7, 23, 16, 22, 58),
#   datetime.datetime(2010, 7, 23, 16, 23, 24),
#   datetime.datetime(2010, 7, 23, 16, 29, 53),
#   datetime.datetime(2010, 7, 23, 17, 53, 25)],
#  [datetime.datetime(2011, 12, 12, 17, 40, 49),
#   datetime.datetime(2012, 1, 3, 18, 15, 12)],
#  [datetime.datetime(2011, 4, 1, 16, 48, 44),
#   datetime.datetime(2011, 4, 1, 16, 49, 20),
#   datetime.datetime(2011, 4, 1, 17, 42, 2),
#   datetime.datetime(2011, 4, 1, 18, 40, 1),
#   datetime.datetime(2011, 4, 4, 18, 5, 40),
#   datetime.datetime(2011, 4, 6, 18, 48, 27)],
#  [datetime.datetime(2010, 3, 8, 20, 43, 25),
#   datetime.datetime(2010, 3, 8, 20, 44, 57),
#   datetime.datetime(2010, 3, 8, 20, 45, 49),
#   datetime.datetime(2010, 3, 8, 20, 52, 48),
#   datetime.datetime(2010, 3, 9, 2, 0, 50)],
#  [datetime.datetime(2012, 1, 25, 16, 58, 57),
#   datetime.datetime(2012, 1, 25, 17, 39, 2),
#   datetime.datetime(2012, 2, 1, 20, 28, 32),
#   datetime.datetime(2012, 2, 29, 2, 21, 41)],
#  [datetime.datetime(2010, 3, 26, 0, 16, 3),
#   datetime.datetime(2010, 3, 26, 0, 32, 12),
#   datetime.datetime(2010, 3, 26, 2, 10, 30)],
#  [datetime.datetime(2012, 4, 20, 18, 47, 22),
#   datetime.datetime(2012, 4, 26, 16, 37, 56),
#   datetime.datetime(2012, 4, 26, 20, 19, 28)],
#  [datetime.datetime(2010, 6, 8, 20, 44, 14),
#   datetime.datetime(2010, 6, 28, 22, 2, 44),
#   datetime.datetime(2010, 6, 28, 22, 7, 25)],
#  [datetime.datetime(2010, 3, 30, 23, 58, 20),
#   datetime.datetime(2010, 3, 30, 23, 58, 35),
#   datetime.datetime(2010, 3, 30, 23, 59, 10),
#   datetime.datetime(2010, 3, 31, 0, 13, 29)],
#  [datetime.datetime(2012, 3, 13, 18, 47, 21),
#   datetime.datetime(2012, 3, 13, 18, 48, 4),
#   datetime.datetime(2012, 3, 14, 23, 35, 22)],
#  [datetime.datetime(2010, 5, 24, 20, 55, 50),
#   datetime.datetime(2010, 5, 25, 23, 38, 49),
#   datetime.datetime(2010, 6, 16, 16, 46, 50),
#   datetime.datetime(2010, 6, 16, 16, 47, 4),
#   datetime.datetime(2010, 6, 21, 23, 4, 47),
#   datetime.datetime(2010, 6, 22, 20, 27, 44)],
#  [datetime.datetime(2011, 10, 7, 17, 50, 2),
#   datetime.datetime(2011, 10, 7, 17, 50, 33)],
#  [datetime.datetime(2010, 11, 25, 23, 2, 43),
#   datetime.datetime(2010, 11, 25, 23, 3, 26),
#   datetime.datetime(2010, 11, 26, 0, 56, 39),
#   datetime.datetime(2010, 11, 30, 1, 25, 15),
#   datetime.datetime(2010, 11, 30, 1, 25, 22),
#   datetime.datetime(2010, 11, 30, 19, 58, 20),
#   datetime.datetime(2010, 12, 1, 23, 33, 8)],
#  [datetime.datetime(2011, 6, 30, 21, 42, 32),
#   datetime.datetime(2011, 6, 30, 21, 42, 53),
#   datetime.datetime(2011, 7, 4, 20, 19, 44),
#   datetime.datetime(2011, 7, 4, 20, 57, 6)],
#  [datetime.datetime(2012, 6, 12, 17, 18, 8),
#   datetime.datetime(2012, 6, 18, 18, 1, 49),
#   datetime.datetime(2012, 7, 2, 17, 44, 23)],
#  [datetime.datetime(2011, 11, 8, 17, 24),
#   datetime.datetime(2011, 11, 8, 17, 24, 19),
#   datetime.datetime(2011, 11, 8, 17, 34, 52)],
#  [datetime.datetime(2012, 5, 2, 18, 41, 57),
#   datetime.datetime(2012, 5, 3, 16, 0, 14),
#   datetime.datetime(2012, 5, 3, 22, 34, 29)],
#  [datetime.datetime(2011, 2, 8, 16, 48, 56),
#   datetime.datetime(2011, 2, 8, 16, 49, 34),
#   datetime.datetime(2011, 2, 8, 19, 49, 59)],
#  [datetime.datetime(2011, 11, 17, 18, 35, 43),
#   datetime.datetime(2011, 11, 17, 18, 36, 1),
#   datetime.datetime(2011, 11, 17, 23, 0, 5)],
#  [datetime.datetime(2010, 9, 7, 22, 11, 7),
#   datetime.datetime(2010, 9, 7, 22, 44, 49),
#   datetime.datetime(2010, 9, 7, 23, 39, 38)],
#  [datetime.datetime(2012, 2, 14, 20, 5, 29),
#   datetime.datetime(2012, 2, 15, 18, 20, 13),
#   datetime.datetime(2012, 3, 1, 0, 31, 24),
#   datetime.datetime(2012, 3, 1, 0, 31, 28)],
#  [datetime.datetime(2010, 10, 13, 18, 21, 33),
#   datetime.datetime(2010, 10, 13, 18, 21, 52),
#   datetime.datetime(2010, 10, 13, 18, 22, 15),
#   datetime.datetime(2010, 10, 20, 23, 23, 37)],
#  [datetime.datetime(2012, 8, 2, 16, 46, 54),
#   datetime.datetime(2012, 8, 2, 16, 48, 49),
#   datetime.datetime(2012, 8, 2, 16, 49, 7)],
#  [datetime.datetime(2012, 7, 27, 21, 10, 43),
#   datetime.datetime(2012, 8, 10, 21, 16, 56),
#   datetime.datetime(2012, 8, 14, 16, 26, 51)],
#  [datetime.datetime(2010, 5, 14, 20, 55, 15),
#   datetime.datetime(2010, 5, 14, 21, 2, 16),
#   datetime.datetime(2010, 5, 14, 21, 24, 16)],
#  [datetime.datetime(2012, 2, 15, 18, 20, 54),
#   datetime.datetime(2012, 2, 15, 18, 30, 22),
#   datetime.datetime(2012, 2, 15, 22, 6, 58),
#   datetime.datetime(2012, 2, 15, 22, 6, 59)],
#  [datetime.datetime(2010, 7, 15, 18, 44, 37),
#   datetime.datetime(2010, 7, 15, 20, 54, 40),
#   datetime.datetime(2010, 7, 15, 21, 10, 18)],
#  [datetime.datetime(2010, 12, 1, 1, 41, 26),
#   datetime.datetime(2010, 12, 1, 18, 11, 18),
#   datetime.datetime(2010, 12, 1, 18, 11, 26)],
#  [datetime.datetime(2012, 3, 22, 1, 34, 29),
#   datetime.datetime(2012, 3, 22, 1, 34, 39),
#   datetime.datetime(2012, 3, 26, 18, 31, 22)],
#  [datetime.datetime(2010, 5, 6, 19, 5, 9),
#   datetime.datetime(2010, 5, 6, 21, 1, 24),
#   datetime.datetime(2010, 5, 6, 21, 27, 7),
#   datetime.datetime(2010, 5, 6, 22, 36, 41),
#   datetime.datetime(2010, 5, 7, 0, 6, 8),
#   datetime.datetime(2010, 5, 7, 20, 17, 30),
#   datetime.datetime(2010, 5, 7, 20, 17, 43)],
#  [datetime.datetime(2010, 11, 20, 1, 53, 47),
#   datetime.datetime(2010, 11, 20, 2, 24, 12),
#   datetime.datetime(2010, 11, 22, 17, 52, 33)],
#  [datetime.datetime(2012, 2, 6, 17, 29, 21),
#   datetime.datetime(2012, 2, 6, 17, 29, 28),
#   datetime.datetime(2012, 2, 6, 17, 57, 12)],
#  [datetime.datetime(2011, 10, 5, 23, 48, 23),
#   datetime.datetime(2011, 10, 6, 17, 30, 22),
#   datetime.datetime(2011, 10, 6, 21, 48, 54)],
#  [datetime.datetime(2012, 5, 7, 15, 41, 52),
#   datetime.datetime(2012, 5, 7, 16, 10, 51),
#   datetime.datetime(2012, 5, 7, 18, 36, 28),
#   datetime.datetime(2012, 5, 15, 20, 35, 47)],
#  [datetime.datetime(2010, 9, 20, 23, 22, 31),
#   datetime.datetime(2010, 9, 20, 23, 23, 7),
#   datetime.datetime(2010, 9, 20, 23, 24, 30)],
#  [datetime.datetime(2012, 6, 22, 16, 2, 35),
#   datetime.datetime(2012, 6, 25, 18, 6, 8),
#   datetime.datetime(2012, 6, 25, 18, 27, 9)],
#  [datetime.datetime(2012, 7, 20, 15, 1, 9),
#   datetime.datetime(2012, 7, 23, 22, 8, 8),
#   datetime.datetime(2012, 7, 23, 22, 21, 41)],
#  [datetime.datetime(2011, 6, 9, 18, 44, 39),
#   datetime.datetime(2011, 7, 1, 15, 47, 17),
#   datetime.datetime(2011, 7, 1, 23, 15, 6),
#   datetime.datetime(2011, 7, 14, 23, 42, 45)],
#  [datetime.datetime(2012, 3, 20, 19, 6, 9),
#   datetime.datetime(2012, 3, 20, 19, 6, 45),
#   datetime.datetime(2012, 3, 20, 19, 7, 16)],
#  [datetime.datetime(2012, 7, 18, 18, 56, 55),
#   datetime.datetime(2012, 7, 18, 21, 29, 20),
#   datetime.datetime(2012, 7, 19, 15, 10, 42)],
#  [datetime.datetime(2011, 4, 14, 16, 29, 40),
#   datetime.datetime(2011, 4, 18, 17, 50, 42),
#   datetime.datetime(2011, 4, 18, 17, 57, 59)],
#  [datetime.datetime(2010, 11, 10, 0, 17, 13),
#   datetime.datetime(2010, 11, 10, 0, 17, 47),
#   datetime.datetime(2010, 11, 19, 0, 11, 59),
#   datetime.datetime(2010, 12, 7, 0, 21, 54),
#   datetime.datetime(2010, 12, 7, 0, 22, 11)],
#  [datetime.datetime(2010, 9, 3, 16, 38, 27),
#   datetime.datetime(2010, 9, 3, 16, 48, 54),
#   datetime.datetime(2010, 9, 6, 23, 27, 5),
#   datetime.datetime(2010, 9, 6, 23, 28, 17)],
#  [datetime.datetime(2012, 5, 28, 22, 36, 21),
#   datetime.datetime(2012, 5, 30, 19, 1, 54),
#   datetime.datetime(2012, 5, 31, 15, 51, 47)],
#  [datetime.datetime(2010, 12, 29, 1, 23, 40),
#   datetime.datetime(2011, 1, 19, 0, 33, 26),
#   datetime.datetime(2011, 1, 19, 0, 40, 19),
#   datetime.datetime(2011, 1, 21, 23, 36, 47),
#   datetime.datetime(2011, 1, 21, 23, 36, 56)],
#  [datetime.datetime(2010, 12, 28, 1, 12, 53),
#   datetime.datetime(2010, 12, 28, 1, 51, 7),
#   datetime.datetime(2011, 1, 20, 19, 48, 38)],
#  [datetime.datetime(2010, 7, 1, 17, 53, 2),
#   datetime.datetime(2010, 7, 1, 20, 33),
#   datetime.datetime(2010, 7, 2, 0, 43, 16),
#   datetime.datetime(2010, 7, 2, 0, 55, 2),
#   datetime.datetime(2010, 7, 2, 20, 15, 7),
#   datetime.datetime(2010, 7, 2, 20, 39, 50)],
#  [datetime.datetime(2010, 11, 25, 20, 50, 31),
#   datetime.datetime(2010, 11, 25, 20, 50, 46),
#   datetime.datetime(2010, 11, 26, 19, 27, 40),
#   datetime.datetime(2010, 12, 14, 0, 43, 50),
#   datetime.datetime(2010, 12, 14, 0, 44, 4)],
#  [datetime.datetime(2012, 9, 6, 16, 45, 4),
#   datetime.datetime(2012, 9, 24, 18, 34, 43)],
#  [datetime.datetime(2011, 2, 1, 23, 2, 3),
#   datetime.datetime(2011, 2, 16, 1, 52, 44),
#   datetime.datetime(2011, 2, 16, 1, 52, 51),
#   datetime.datetime(2011, 2, 21, 23, 6, 23)],
#  [datetime.datetime(2010, 4, 12, 17, 39, 32),
#   datetime.datetime(2010, 4, 29, 22, 33, 17),
#   datetime.datetime(2010, 4, 29, 22, 33, 23)],
#  [datetime.datetime(2012, 1, 10, 18, 59, 44),
#   datetime.datetime(2012, 1, 10, 18, 59, 56),
#   datetime.datetime(2012, 1, 10, 20, 7, 13)],
#  [datetime.datetime(2011, 10, 28, 19, 3, 5),
#   datetime.datetime(2011, 11, 2, 17, 42, 11),
#   datetime.datetime(2011, 11, 2, 17, 43, 41),
#   datetime.datetime(2011, 11, 16, 20, 49, 39),
#   datetime.datetime(2011, 11, 17, 17, 53, 58)],
#  [datetime.datetime(2010, 10, 5, 23, 7, 26),
#   datetime.datetime(2010, 10, 7, 16, 27, 5),
#   datetime.datetime(2010, 10, 8, 18, 32, 11),
#   datetime.datetime(2010, 10, 8, 21, 55, 2),
#   datetime.datetime(2010, 10, 8, 22, 7, 16)],
#  [datetime.datetime(2011, 4, 29, 23, 36, 5),
#   datetime.datetime(2011, 4, 29, 23, 36, 29),
#   datetime.datetime(2011, 5, 2, 16, 10, 10),
#   datetime.datetime(2011, 5, 3, 18, 37, 8),
#   datetime.datetime(2011, 5, 3, 18, 37, 23)],
#  [datetime.datetime(2010, 8, 23, 17, 13, 2),
#   datetime.datetime(2010, 8, 23, 17, 13, 22),
#   datetime.datetime(2010, 8, 23, 17, 14, 7)],
#  [datetime.datetime(2012, 4, 20, 18, 54, 26),
#   datetime.datetime(2012, 4, 20, 18, 54, 41),
#   datetime.datetime(2012, 4, 23, 17, 14, 28)],
#  [datetime.datetime(2012, 7, 19, 18, 55, 1),
#   datetime.datetime(2012, 7, 20, 18, 25, 48),
#   datetime.datetime(2012, 7, 20, 18, 26, 36)],
#  [datetime.datetime(2012, 5, 14, 20, 36, 2),
#   datetime.datetime(2012, 5, 15, 23, 4, 27),
#   datetime.datetime(2012, 5, 15, 23, 7, 3),
#   datetime.datetime(2012, 5, 16, 23, 57, 16)],
#  [datetime.datetime(2012, 3, 6, 20, 18, 20),
#   datetime.datetime(2012, 3, 7, 1, 53, 18),
#   datetime.datetime(2012, 3, 14, 19, 55, 59),
#   datetime.datetime(2012, 3, 16, 1, 3, 14)],
#  [datetime.datetime(2011, 12, 21, 22, 53, 6),
#   datetime.datetime(2011, 12, 23, 0, 56, 27)],
#  [datetime.datetime(2010, 4, 19, 18, 48, 19),
#   datetime.datetime(2010, 6, 2, 0, 10, 52),
#   datetime.datetime(2010, 6, 2, 0, 14, 57)],
#  [datetime.datetime(2012, 1, 20, 2, 2, 37),
#   datetime.datetime(2012, 1, 20, 2, 2, 55),
#   datetime.datetime(2012, 1, 20, 23, 47, 10)],
#  [datetime.datetime(2011, 8, 1, 16, 2, 40),
#   datetime.datetime(2011, 8, 19, 17, 29, 29),
#   datetime.datetime(2011, 8, 19, 17, 29, 29)],
#  [datetime.datetime(2011, 12, 28, 22, 37),
#   datetime.datetime(2012, 1, 18, 20, 36, 11),
#   datetime.datetime(2012, 2, 2, 18, 12, 36),
#   datetime.datetime(2012, 2, 7, 20, 21, 54)],
#  [datetime.datetime(2010, 3, 29, 18, 12, 13),
#   datetime.datetime(2010, 4, 1, 22, 17, 35),
#   datetime.datetime(2010, 4, 1, 22, 17, 42)],
#  [datetime.datetime(2012, 5, 8, 18, 48, 14),
#   datetime.datetime(2012, 5, 8, 18, 48, 50),
#   datetime.datetime(2012, 5, 8, 18, 48, 51)],
#  [datetime.datetime(2010, 11, 25, 2, 20, 43),
#   datetime.datetime(2010, 11, 30, 1, 49, 8),
#   datetime.datetime(2010, 11, 30, 1, 49, 26)],
#  [datetime.datetime(2011, 8, 3, 23, 10, 21),
#   datetime.datetime(2011, 8, 3, 23, 11, 53),
#   datetime.datetime(2011, 8, 4, 21, 52, 59),
#   datetime.datetime(2011, 8, 4, 21, 53, 4)],
#  [datetime.datetime(2011, 1, 10, 17, 39, 15),
#   datetime.datetime(2011, 1, 10, 17, 41, 44),
#   datetime.datetime(2011, 1, 27, 1, 34, 13),
#   datetime.datetime(2011, 2, 9, 2, 0, 42)],
#  [datetime.datetime(2012, 6, 19, 21, 23, 59),
#   datetime.datetime(2012, 6, 20, 15, 46, 29),
#   datetime.datetime(2012, 6, 20, 16, 11, 35)],
#  [datetime.datetime(2012, 7, 11, 22, 50, 14),
#   datetime.datetime(2012, 7, 12, 14, 59, 23),
#   datetime.datetime(2012, 7, 12, 15, 7, 56)],
#  [datetime.datetime(2010, 9, 17, 22, 2, 58),
#   datetime.datetime(2010, 9, 17, 23, 48, 16),
#   datetime.datetime(2010, 9, 21, 20, 27, 7),
#   datetime.datetime(2010, 9, 21, 20, 27, 19)],
#  [datetime.datetime(2010, 12, 28, 22, 15, 48),
#   datetime.datetime(2011, 1, 21, 17, 44, 16),
#   datetime.datetime(2011, 1, 21, 17, 44, 48)],
#  [datetime.datetime(2010, 2, 10, 1, 17, 6),
#   datetime.datetime(2010, 2, 24, 1, 40, 34),
#   datetime.datetime(2010, 3, 16, 18, 5, 38)],
#  [datetime.datetime(2012, 2, 23, 18, 45, 1),
#   datetime.datetime(2012, 3, 13, 0, 6, 36),
#   datetime.datetime(2012, 3, 14, 2, 53, 46),
#   datetime.datetime(2012, 3, 30, 22, 0, 29)],
#  [datetime.datetime(2010, 4, 9, 15, 36, 35),
#   datetime.datetime(2010, 4, 13, 23, 40, 30),
#   datetime.datetime(2010, 4, 14, 17, 22, 18),
#   datetime.datetime(2010, 4, 14, 17, 22, 26)],
#  [datetime.datetime(2010, 12, 29, 18, 6, 43),
#   datetime.datetime(2010, 12, 29, 18, 6, 53),
#   datetime.datetime(2010, 12, 29, 19, 49, 51),
#   datetime.datetime(2010, 12, 29, 23, 46, 12),
#   datetime.datetime(2010, 12, 29, 23, 47, 1)],
#  [datetime.datetime(2012, 7, 10, 22, 42, 22),
#   datetime.datetime(2012, 7, 10, 22, 42, 32),
#   datetime.datetime(2012, 7, 12, 17, 22, 46)],
#  [datetime.datetime(2011, 6, 22, 21, 8, 2),
#   datetime.datetime(2011, 6, 22, 21, 8, 20),
#   datetime.datetime(2011, 6, 22, 23, 55, 26),
#   datetime.datetime(2011, 6, 23, 16, 18, 51),
#   datetime.datetime(2011, 6, 23, 16, 18, 54),
#   datetime.datetime(2011, 7, 20, 16, 13, 16),
#   datetime.datetime(2011, 8, 3, 22, 3, 51)],
#  [datetime.datetime(2011, 7, 13, 22, 3, 38),
#   datetime.datetime(2011, 7, 14, 16, 37, 19),
#   datetime.datetime(2011, 7, 14, 16, 51, 59),
#   datetime.datetime(2011, 7, 14, 17, 23, 3)],
#  [datetime.datetime(2012, 1, 26, 19, 51, 34),
#   datetime.datetime(2012, 1, 26, 19, 51, 43),
#   datetime.datetime(2012, 1, 26, 20, 56, 27)],
#  [datetime.datetime(2012, 5, 24, 22, 8, 38),
#   datetime.datetime(2012, 5, 24, 23, 18, 41),
#   datetime.datetime(2012, 5, 25, 17, 15, 20)],
#  [datetime.datetime(2011, 12, 16, 22, 58, 26),
#   datetime.datetime(2011, 12, 16, 22, 59, 19),
#   datetime.datetime(2011, 12, 29, 1, 27, 41)],
#  [datetime.datetime(2012, 5, 10, 20, 25, 17),
#   datetime.datetime(2012, 5, 10, 20, 25, 31),
#   datetime.datetime(2012, 5, 10, 20, 30, 11)],
#  [datetime.datetime(2010, 5, 4, 18, 50, 27),
#   datetime.datetime(2010, 5, 5, 18, 35, 13),
#   datetime.datetime(2010, 5, 5, 18, 35, 24),
#   datetime.datetime(2010, 5, 17, 16, 11, 7),
# ...
#   datetime.datetime(2012, 8, 7, 18, 53, 38),
#   datetime.datetime(2012, 8, 7, 18, 53, 39)],
#  [datetime.datetime(2012, 7, 26, 18, 9, 20),
#   datetime.datetime(2012, 7, 26, 18, 22, 56),
#   datetime.datetime(2012, 7, 27, 16, 54, 16)],
#  [datetime.datetime(2011, 10, 18, 20, 6, 24),
#   datetime.datetime(2011, 10, 18, 21, 17, 30),
#   datetime.datetime(2011, 10, 18, 21, 17, 31),
#   datetime.datetime(2011, 10, 20, 15, 45, 22),
#   datetime.datetime(2011, 10, 20, 16, 14, 31),
#   datetime.datetime(2011, 10, 20, 16, 14, 31)],
#  [datetime.datetime(2012, 7, 18, 16, 23, 30),
#   datetime.datetime(2012, 7, 18, 16, 23, 42),
#   datetime.datetime(2012, 7, 18, 20, 24, 11)],
#  [datetime.datetime(2011, 10, 13, 15, 17, 13),
#   datetime.datetime(2011, 10, 14, 20, 41, 30),
#   datetime.datetime(2011, 10, 14, 21, 22, 9)],
#  [datetime.datetime(2011, 3, 1, 17, 24, 41),
#   datetime.datetime(2011, 3, 1, 17, 25, 14),
#   datetime.datetime(2011, 3, 1, 20, 29, 13)],
#  [datetime.datetime(2012, 7, 31, 22, 43, 10),
#   datetime.datetime(2012, 8, 2, 16, 22, 59),
#   datetime.datetime(2012, 8, 14, 18, 57, 41),
#   datetime.datetime(2012, 8, 22, 23, 6, 48),
#   datetime.datetime(2012, 9, 6, 22, 38, 27)],
#  [datetime.datetime(2011, 5, 25, 17, 38, 13),
#   datetime.datetime(2011, 5, 25, 17, 38, 37),
#   datetime.datetime(2011, 5, 26, 16, 43, 14),
#   datetime.datetime(2011, 6, 1, 17, 54, 3),
#   datetime.datetime(2011, 6, 7, 15, 44, 55),
#   datetime.datetime(2011, 6, 7, 18, 32, 28),
#   datetime.datetime(2011, 6, 7, 22, 24, 59),
#   datetime.datetime(2011, 6, 7, 22, 28, 58),
#   datetime.datetime(2011, 6, 22, 21, 1, 13),
#   datetime.datetime(2011, 6, 22, 21, 2, 19)],
#  [datetime.datetime(2012, 2, 28, 19, 47, 9),
#   datetime.datetime(2012, 2, 28, 19, 47, 25),
#   datetime.datetime(2012, 2, 29, 1, 40, 58)],
#  [datetime.datetime(2012, 7, 30, 23, 42, 21),
#   datetime.datetime(2012, 7, 31, 23, 23, 18),
#   datetime.datetime(2012, 8, 28, 23, 3, 21)],
#  [datetime.datetime(2011, 10, 26, 23, 30, 54),
#   datetime.datetime(2011, 11, 2, 17, 13, 17),
#   datetime.datetime(2011, 11, 2, 17, 13, 25)],
#  [datetime.datetime(2011, 9, 5, 22, 28, 2),
#   datetime.datetime(2011, 9, 9, 18, 3, 27),
#   datetime.datetime(2011, 9, 15, 18, 57, 15),
#   datetime.datetime(2011, 9, 15, 23, 6, 12)],
#  [datetime.datetime(2011, 5, 26, 16, 26, 22),
#   datetime.datetime(2011, 5, 26, 16, 26, 50),
#   datetime.datetime(2011, 5, 31, 23, 0, 20)],
#  [datetime.datetime(2012, 1, 5, 17, 26, 10),
#   datetime.datetime(2012, 1, 5, 17, 26, 27),
#   datetime.datetime(2012, 1, 5, 19, 20, 52)],
#  [datetime.datetime(2010, 4, 28, 21, 40, 5),
#   datetime.datetime(2010, 5, 12, 17, 51, 57),
#   datetime.datetime(2010, 5, 12, 17, 52, 3)],
#  [datetime.datetime(2012, 7, 31, 15, 20, 5),
#   datetime.datetime(2012, 7, 31, 15, 20, 14),
#   datetime.datetime(2012, 7, 31, 18, 24, 45)],
#  [datetime.datetime(2010, 11, 16, 19, 40, 24),
#   datetime.datetime(2010, 11, 16, 19, 40, 56),
#   datetime.datetime(2010, 11, 16, 20, 32, 57)],
#  [datetime.datetime(2012, 5, 17, 22, 34, 2),
#   datetime.datetime(2012, 5, 17, 23, 7, 53),
#   datetime.datetime(2012, 5, 18, 22, 22, 22)],
#  [datetime.datetime(2012, 1, 10, 22, 31, 21),
#   datetime.datetime(2012, 1, 13, 17, 28, 55),
#   datetime.datetime(2012, 1, 13, 17, 28, 56)],
#  [datetime.datetime(2012, 1, 18, 18, 39, 21),
#   datetime.datetime(2012, 1, 18, 20, 23, 37),
#   datetime.datetime(2012, 1, 18, 23, 14, 2)],
#  [datetime.datetime(2012, 4, 11, 20, 51, 59),
#   datetime.datetime(2012, 4, 11, 20, 52, 12),
#   datetime.datetime(2012, 4, 16, 17, 54, 56)],
#  [datetime.datetime(2010, 2, 10, 1, 7, 4),
#   datetime.datetime(2010, 2, 10, 1, 7, 11),
#   datetime.datetime(2010, 2, 10, 1, 7, 18)],
#  [datetime.datetime(2012, 3, 28, 17, 3, 55),
#   datetime.datetime(2012, 3, 28, 17, 4, 21),
#   datetime.datetime(2012, 3, 28, 17, 8)],
#  [datetime.datetime(2012, 1, 11, 19, 52, 28),
#   datetime.datetime(2012, 1, 11, 22, 40, 5),
#   datetime.datetime(2012, 1, 19, 0, 15, 37)],
#  [datetime.datetime(2012, 1, 18, 19, 23, 55),
#   datetime.datetime(2012, 1, 18, 19, 24, 6),
#   datetime.datetime(2012, 1, 18, 22, 50, 24)],
#  [datetime.datetime(2012, 7, 17, 15, 22, 25),
#   datetime.datetime(2012, 7, 17, 15, 22, 33),
#   datetime.datetime(2012, 7, 17, 20, 52, 35)],
#  [datetime.datetime(2012, 6, 8, 16, 3, 5),
#   datetime.datetime(2012, 6, 8, 16, 3, 28),
#   datetime.datetime(2012, 6, 14, 15, 56, 56),
#   datetime.datetime(2012, 7, 13, 21, 19, 37)],
#  [datetime.datetime(2012, 6, 12, 16, 23, 44),
#   datetime.datetime(2012, 6, 15, 14, 56, 23)],
#  [datetime.datetime(2012, 6, 18, 18, 44, 18),
#   datetime.datetime(2012, 6, 18, 22, 46, 31),
#   datetime.datetime(2012, 6, 18, 22, 46, 46)],
#  [datetime.datetime(2012, 1, 10, 1, 23, 38),
#   datetime.datetime(2012, 1, 10, 1, 23, 57),
#   datetime.datetime(2012, 1, 17, 20, 49, 33)],
#  [datetime.datetime(2011, 12, 14, 0, 51, 46),
#   datetime.datetime(2011, 12, 14, 0, 52, 10),
#   datetime.datetime(2011, 12, 14, 1, 57, 49)],
#  [datetime.datetime(2011, 1, 19, 18, 17, 21),
#   datetime.datetime(2011, 1, 25, 19, 28, 10),
#   datetime.datetime(2011, 1, 26, 1, 33, 5),
#   datetime.datetime(2011, 2, 9, 20, 37, 25),
#   datetime.datetime(2011, 2, 9, 20, 37, 34)],
#  [datetime.datetime(2010, 8, 11, 20, 41, 35),
#   datetime.datetime(2010, 8, 30, 23, 3, 37),
#   datetime.datetime(2010, 8, 30, 23, 4, 4),
#   datetime.datetime(2010, 9, 13, 16, 50, 59),
#   datetime.datetime(2010, 9, 13, 16, 51, 37),
#   datetime.datetime(2010, 9, 13, 18, 33, 1),
#   datetime.datetime(2010, 9, 13, 18, 33, 6),
#   datetime.datetime(2010, 9, 13, 18, 33, 18),
#   datetime.datetime(2010, 9, 13, 18, 33, 27),
#   datetime.datetime(2010, 9, 20, 17, 4, 20),
#   datetime.datetime(2010, 9, 20, 17, 4, 28)],
#  [datetime.datetime(2012, 7, 23, 19, 1, 18),
#   datetime.datetime(2012, 7, 23, 23, 1, 5),
#   datetime.datetime(2012, 7, 25, 16, 28)],
#  [datetime.datetime(2011, 4, 4, 18, 13, 39),
#   datetime.datetime(2011, 4, 4, 18, 14, 4),
#   datetime.datetime(2011, 4, 4, 18, 16, 27)],
#  [datetime.datetime(2011, 1, 11, 20, 54, 55),
#   datetime.datetime(2011, 1, 14, 17, 33, 59),
#   datetime.datetime(2011, 1, 14, 17, 52, 6)],
#  [datetime.datetime(2010, 12, 14, 20, 4, 53),
#   datetime.datetime(2010, 12, 14, 20, 5, 16),
#   datetime.datetime(2010, 12, 14, 20, 5, 33)],
#  [datetime.datetime(2011, 10, 25, 15, 25, 2),
#   datetime.datetime(2011, 10, 25, 15, 26, 54),
#   datetime.datetime(2011, 10, 25, 17, 50, 54)],
#  [datetime.datetime(2010, 10, 11, 16, 44, 4),
#   datetime.datetime(2010, 10, 11, 23, 25, 4),
#   datetime.datetime(2010, 10, 11, 23, 25, 54)],
#  [datetime.datetime(2010, 5, 25, 0, 34, 26),
#   datetime.datetime(2010, 6, 30, 0, 11, 34),
#   datetime.datetime(2010, 6, 30, 0, 18, 5)],
#  [datetime.datetime(2010, 10, 5, 16, 3, 32),
#   datetime.datetime(2010, 10, 6, 16, 51, 51),
#   datetime.datetime(2010, 10, 6, 16, 59, 12)],
#  [datetime.datetime(2012, 1, 11, 0, 57, 1),
#   datetime.datetime(2012, 1, 16, 17, 53, 10),
#   datetime.datetime(2012, 1, 28, 0, 32, 26),
#   datetime.datetime(2012, 2, 1, 2, 4, 22)],
#  [datetime.datetime(2012, 5, 21, 15, 18, 26),
#   datetime.datetime(2012, 5, 21, 15, 19, 22),
#   datetime.datetime(2012, 5, 21, 15, 26, 51),
#   datetime.datetime(2012, 5, 21, 16, 22),
#   datetime.datetime(2012, 5, 21, 16, 22, 1)],
#  [datetime.datetime(2010, 9, 16, 20, 40, 30),
#   datetime.datetime(2010, 9, 22, 21, 6, 53),
#   datetime.datetime(2010, 9, 23, 16, 55, 5),
#   datetime.datetime(2010, 9, 30, 21, 1, 1),
#   datetime.datetime(2010, 9, 30, 21, 1, 10)],
#  [datetime.datetime(2011, 9, 14, 23, 45, 59),
#   datetime.datetime(2011, 9, 26, 23, 57, 4),
#   datetime.datetime(2011, 9, 28, 15, 56, 30)],
#  [datetime.datetime(2011, 6, 23, 15, 35, 48),
#   datetime.datetime(2011, 6, 23, 15, 36, 8),
#   datetime.datetime(2011, 6, 23, 17, 52),
#   datetime.datetime(2011, 6, 23, 18, 0, 20),
#   datetime.datetime(2011, 7, 21, 21, 33, 50),
#   datetime.datetime(2011, 7, 21, 21, 33, 58)],
#  [datetime.datetime(2011, 4, 14, 15, 32, 36),
#   datetime.datetime(2011, 4, 14, 15, 58, 44),
#   datetime.datetime(2011, 4, 14, 23, 3, 2)],
#  [datetime.datetime(2012, 7, 18, 17, 0, 13),
#   datetime.datetime(2012, 7, 20, 15, 52, 34),
#   datetime.datetime(2012, 7, 20, 18, 7, 28)],
#  [datetime.datetime(2011, 1, 26, 23, 45, 2),
#   datetime.datetime(2011, 1, 27, 17, 40, 54),
#   datetime.datetime(2011, 1, 31, 22, 34, 41)],
#  [datetime.datetime(2012, 7, 24, 15, 38, 39),
#   datetime.datetime(2012, 7, 24, 15, 39, 1)],
#  [datetime.datetime(2010, 9, 15, 15, 50, 56),
#   datetime.datetime(2010, 9, 15, 15, 51, 39),
#   datetime.datetime(2010, 9, 15, 15, 52, 2)],
#  [datetime.datetime(2010, 10, 25, 21, 16, 1),
#   datetime.datetime(2010, 10, 26, 15, 49, 21),
#   datetime.datetime(2010, 10, 26, 15, 50, 24)],
#  [datetime.datetime(2011, 2, 14, 18, 3, 48),
#   datetime.datetime(2011, 2, 14, 18, 4, 20),
#   datetime.datetime(2011, 2, 16, 1, 14, 19),
#   datetime.datetime(2011, 3, 14, 18, 31, 2),
#   datetime.datetime(2011, 3, 14, 18, 31, 18)],
#  [datetime.datetime(2011, 6, 17, 23, 59, 46),
#   datetime.datetime(2011, 6, 18, 0, 0, 22),
#   datetime.datetime(2011, 7, 7, 0, 8, 34),
#   datetime.datetime(2011, 7, 19, 15, 57, 22),
#   datetime.datetime(2011, 7, 19, 15, 57, 23)],
#  [datetime.datetime(2012, 7, 30, 23, 3, 11),
#   datetime.datetime(2012, 7, 31, 21, 37, 16)],
#  [datetime.datetime(2011, 1, 31, 18, 12, 34),
#   datetime.datetime(2011, 1, 31, 19, 43, 27),
#   datetime.datetime(2011, 2, 2, 1, 37, 1)],
#  [datetime.datetime(2011, 12, 13, 17, 19, 55),
#   datetime.datetime(2011, 12, 13, 20, 13, 25),
#   datetime.datetime(2011, 12, 13, 20, 22, 43)],
#  [datetime.datetime(2012, 3, 19, 19, 50, 29),
#   datetime.datetime(2012, 3, 29, 22, 18, 31),
#   datetime.datetime(2012, 4, 2, 15, 52, 47),
#   datetime.datetime(2012, 4, 2, 17, 5, 6)],
#  [datetime.datetime(2010, 6, 22, 22, 33, 44),
#   datetime.datetime(2010, 6, 30, 23, 24, 53),
#   datetime.datetime(2010, 7, 1, 17, 2, 51),
#   datetime.datetime(2010, 7, 6, 17, 36, 29),
#   datetime.datetime(2010, 7, 6, 18, 36, 50),
#   datetime.datetime(2010, 7, 12, 16, 37, 51),
#   datetime.datetime(2010, 7, 14, 22, 2, 2),
#   datetime.datetime(2010, 7, 15, 18, 19, 2)],
#  [datetime.datetime(2011, 5, 18, 16, 34, 39),
#   datetime.datetime(2011, 5, 18, 16, 35, 1),
#   datetime.datetime(2011, 5, 18, 23, 55, 18)],
#  [datetime.datetime(2012, 1, 12, 0, 59, 39),
#   datetime.datetime(2012, 1, 16, 18, 46, 4),
#   datetime.datetime(2012, 1, 16, 20, 20, 57),
#   datetime.datetime(2012, 1, 16, 20, 21, 55),
#   datetime.datetime(2012, 1, 16, 20, 45, 15)],
#  [datetime.datetime(2011, 12, 12, 19, 23, 38),
#   datetime.datetime(2011, 12, 12, 20, 37, 24),
#   datetime.datetime(2011, 12, 13, 23, 0, 43)],
#  [datetime.datetime(2011, 4, 5, 16, 7),
#   datetime.datetime(2011, 4, 5, 16, 7, 14),
#   datetime.datetime(2011, 4, 5, 16, 9, 39)],
#  [datetime.datetime(2010, 7, 1, 22, 30, 32),
#   datetime.datetime(2010, 8, 9, 17, 34, 20),
#   datetime.datetime(2010, 8, 9, 17, 34, 30),
#   datetime.datetime(2010, 8, 11, 0, 6, 20),
#   datetime.datetime(2010, 8, 11, 0, 7, 4)],
#  [datetime.datetime(2012, 2, 13, 18, 15, 33),
#   datetime.datetime(2012, 2, 13, 18, 19, 18),
#   datetime.datetime(2012, 2, 13, 20, 42, 19)],
#  [datetime.datetime(2011, 3, 4, 18, 29, 57),
#   datetime.datetime(2011, 3, 4, 18, 30, 34),
#   datetime.datetime(2011, 3, 18, 17, 21, 6)],
#  [datetime.datetime(2010, 7, 8, 23, 35, 41),
#   datetime.datetime(2010, 7, 8, 23, 41, 10),
#   datetime.datetime(2010, 7, 8, 23, 41, 22),
#   datetime.datetime(2010, 7, 9, 16, 38, 50),
#   datetime.datetime(2010, 7, 9, 16, 38, 59)],
#  [datetime.datetime(2010, 5, 20, 21, 58, 47),
#   datetime.datetime(2010, 5, 27, 0, 12, 55),
#   datetime.datetime(2010, 5, 27, 0, 14, 20)],
#  [datetime.datetime(2012, 8, 10, 14, 49, 50),
#   datetime.datetime(2012, 8, 10, 15, 33, 45),
#   datetime.datetime(2012, 8, 10, 15, 42, 42)],
#  [datetime.datetime(2011, 10, 5, 16, 59),
#   datetime.datetime(2011, 10, 21, 16, 18, 58),
#   datetime.datetime(2011, 10, 21, 16, 27, 54)],
#  [datetime.datetime(2012, 7, 24, 15, 22, 2),
#   datetime.datetime(2012, 7, 24, 16, 11, 53),
#   datetime.datetime(2012, 7, 24, 22, 39, 54)],
#  [datetime.datetime(2012, 5, 3, 23, 51, 50),
#   datetime.datetime(2012, 5, 10, 0, 6, 27),
#   datetime.datetime(2012, 5, 10, 17, 19, 59)],
#  [datetime.datetime(2011, 3, 4, 18, 10, 16),
#   datetime.datetime(2011, 3, 4, 18, 10, 37),
#   datetime.datetime(2011, 3, 4, 18, 25, 12),
#   datetime.datetime(2011, 4, 14, 16, 43, 4),
#   datetime.datetime(2011, 4, 14, 16, 43, 14)],
#  [datetime.datetime(2012, 1, 2, 19, 49, 47),
#   datetime.datetime(2012, 1, 2, 19, 49, 58),
#   datetime.datetime(2012, 1, 2, 21, 0, 55),
#   datetime.datetime(2012, 1, 2, 21, 0, 56)],
#  [datetime.datetime(2010, 2, 9, 0, 6, 58),
#   datetime.datetime(2010, 2, 9, 0, 12),
#   datetime.datetime(2010, 2, 9, 0, 12, 28),
#   datetime.datetime(2010, 2, 26, 1, 56, 34),
#   datetime.datetime(2010, 2, 26, 18, 9, 32)],
#  [datetime.datetime(2012, 3, 27, 17, 53, 32),
#   datetime.datetime(2012, 3, 29, 15, 37, 55)],
#  [datetime.datetime(2011, 1, 10, 19, 50, 41),
#   datetime.datetime(2011, 1, 12, 17, 54, 14),
#   datetime.datetime(2011, 1, 12, 18, 32, 22),
#   datetime.datetime(2011, 1, 12, 23, 40, 13)],
#  [datetime.datetime(2012, 1, 24, 22, 27, 17),
#   datetime.datetime(2012, 1, 31, 20, 29, 27),
#   datetime.datetime(2012, 2, 7, 19, 1, 30)],
#  [datetime.datetime(2010, 2, 2, 19, 17, 37),
#   datetime.datetime(2010, 2, 16, 1, 21, 37),
#   datetime.datetime(2010, 2, 16, 1, 22, 30)],
#  [datetime.datetime(2011, 12, 20, 18, 21, 55),
#   datetime.datetime(2011, 12, 20, 18, 44, 46),
#   datetime.datetime(2011, 12, 21, 19, 9, 33),
#   datetime.datetime(2011, 12, 21, 20, 24, 14),
#   datetime.datetime(2011, 12, 23, 0, 48, 16)],
#  [datetime.datetime(2012, 3, 8, 0, 57, 18),
#   datetime.datetime(2012, 3, 8, 0, 59, 42),
#   datetime.datetime(2012, 3, 8, 0, 59, 43)],
#  [datetime.datetime(2012, 2, 22, 0, 27, 29),
#   datetime.datetime(2012, 2, 22, 17, 57, 31),
#   datetime.datetime(2012, 2, 22, 19, 17, 46)],
#  [datetime.datetime(2011, 6, 8, 21, 51, 32),
#   datetime.datetime(2011, 6, 9, 15, 7, 27),
#   datetime.datetime(2011, 6, 14, 0, 17, 20)],
#  [datetime.datetime(2012, 5, 15, 15, 7, 16),
#   datetime.datetime(2012, 5, 15, 15, 16),
#   datetime.datetime(2012, 5, 15, 21, 59, 20)],
#  [datetime.datetime(2010, 9, 6, 18, 26, 13),
#   datetime.datetime(2010, 9, 8, 22, 56, 29),
#   datetime.datetime(2010, 9, 9, 15, 37, 19),
#   datetime.datetime(2010, 9, 9, 15, 56, 27)],
#  [datetime.datetime(2011, 9, 8, 21, 30, 42),
#   datetime.datetime(2011, 10, 3, 18, 32, 48),
#   datetime.datetime(2011, 10, 3, 18, 39, 13)],
#  [datetime.datetime(2010, 6, 30, 17, 8, 26),
#   datetime.datetime(2010, 7, 29, 21, 25, 46),
#   datetime.datetime(2010, 7, 29, 21, 38, 22),
#   datetime.datetime(2010, 7, 30, 16, 8, 27),
#   datetime.datetime(2010, 7, 30, 16, 8, 57),
#   datetime.datetime(2010, 8, 4, 18, 52, 2),
#   datetime.datetime(2010, 8, 5, 18, 53, 57)],
#  [datetime.datetime(2011, 6, 13, 17, 22, 41),
#   datetime.datetime(2011, 6, 13, 17, 22, 52),
#   datetime.datetime(2011, 6, 13, 17, 23, 20)],
#  [datetime.datetime(2011, 3, 3, 23, 28, 56),
#   datetime.datetime(2011, 3, 3, 23, 29, 37),
#   datetime.datetime(2011, 3, 5, 2, 0, 5)],
#  [datetime.datetime(2011, 5, 4, 21, 49, 39),
#   datetime.datetime(2011, 5, 18, 18, 28, 5),
#   datetime.datetime(2011, 5, 18, 18, 43, 36),
#   datetime.datetime(2011, 5, 24, 17, 31, 18)],
#  [datetime.datetime(2012, 2, 10, 17, 59, 22),
#   datetime.datetime(2012, 2, 10, 17, 59, 55),
#   datetime.datetime(2012, 2, 11, 2, 5, 32)],
#  [datetime.datetime(2011, 4, 18, 18, 48, 58),
#   datetime.datetime(2011, 4, 19, 16, 39, 22),
#   datetime.datetime(2011, 4, 19, 18, 48, 39)],
#  [datetime.datetime(2010, 5, 24, 20, 25, 24),
#   datetime.datetime(2010, 6, 4, 21, 4, 7),
#   datetime.datetime(2010, 6, 4, 21, 4, 18),
#   datetime.datetime(2010, 6, 4, 21, 5, 47)],
#  [datetime.datetime(2011, 5, 19, 23, 29, 29),
#   datetime.datetime(2011, 5, 19, 23, 29, 52),
#   datetime.datetime(2011, 5, 20, 15, 56, 24)],
#  [datetime.datetime(2011, 1, 4, 23, 22, 59),
#   datetime.datetime(2011, 1, 20, 17, 29, 18),
#   datetime.datetime(2011, 1, 21, 18, 45, 18)],
#  [datetime.datetime(2011, 3, 15, 18, 6, 36),
#   datetime.datetime(2011, 3, 15, 18, 11, 14),
#   datetime.datetime(2011, 3, 15, 18, 16, 59),
#   datetime.datetime(2011, 3, 15, 18, 29, 40)],
#  [datetime.datetime(2012, 2, 7, 19, 27, 5),
#   datetime.datetime(2012, 2, 7, 20, 4, 13),
#   datetime.datetime(2012, 2, 8, 22, 35, 19)],
#  ...]

# %%
len(timeseqs2[0])
# Out:
# 3

# %%
fold3 = lines[2*elems_per_fold:]
fold3_t = timeseqs[2*elems_per_fold:]
fold3_t2 = timeseqs2[2*elems_per_fold:]
fold3_t3 = timeseqs3[2*elems_per_fold:]
#fold3_t4 = timeseqs4[2*elems_per_fold:]

lines = fold3
lines_t = fold3_t
lines_t2 = fold3_t2
lines_t3 = fold3_t3
#lines_t4 = fold1_t4 + fold2_t4

# %%
elems_per_fold, len(lines), len(lines_t), len(lines_t2), len(lines_t3)
# Out:
# (1268, 1268, 1268, 1268, 1268)

# %%
# set parameters
predict_size = 1

# load model, set this to the model generated by train.py
#model = load_model('output_files/models/model_168-0.50.h5')
model = load_model('output_files/models/model_02-1.58.h5')
# Out:
# /Users/hoangnguyen/miniconda3/envs/pydata2/lib/python2.7/site-packages/theano/tensor/basic.py:5130: UserWarning: flatten outdim parameter is deprecated, use ndim instead.
#   "flatten outdim parameter is deprecated, use ndim instead.")

# %%
len(timeseqs3[0])
# Out:
# 3

# %% [markdown]
# # Helper functions

# %%
# define helper functions
def encode(sentence, times, times3, maxlen=maxlen):
    num_features = len(chars)+5
    X = np.zeros((1, maxlen, num_features), dtype=np.float32)
    leftpad = maxlen-len(sentence)
    times2 = np.cumsum(times)
    for t, char in enumerate(sentence):
        midnight = times3[t].replace(hour=0, minute=0, second=0, microsecond=0)
        timesincemidnight = times3[t]-midnight
        multiset_abstraction = Counter(sentence[:t+1])
        for c in chars:
            if c==char:
                X[0, t+leftpad, char_indices[c]] = 1
        X[0, t+leftpad, len(chars)] = t+1
        X[0, t+leftpad, len(chars)+1] = times[t]/divisor
        X[0, t+leftpad, len(chars)+2] = times2[t]/divisor2
        X[0, t+leftpad, len(chars)+3] = timesincemidnight.seconds/86400
        X[0, t+leftpad, len(chars)+4] = times3[t].weekday()/7
    return X

# %%
def getSymbol(predictions):
    maxPrediction = 0
    symbol = ''
    i = 0;
    for prediction in predictions:
        if(prediction>=maxPrediction):
            maxPrediction = prediction
            symbol = target_indices_char[i]
        i += 1
    return symbol

# %% [markdown]
# # Prediction

# %%
one_ahead_gt = []
one_ahead_pred = []

two_ahead_gt = []
two_ahead_pred = []

three_ahead_gt = []
three_ahead_pred = []

# %%
# make predictions
with open('output_files/results/next_activity_and_time_%s' % eventlog, 'wb') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)
    spamwriter.writerow(["Prefix length", "Groud truth", "Predicted", "Levenshtein", "Damerau", "Jaccard", "Ground truth times", "Predicted times", "RMSE", "MAE", "Median AE"])
    for prefix_size in range(2,maxlen):
        print(prefix_size)
        for line, times, times3 in izip(lines, lines_t, lines_t3):
            times.append(0)
            cropped_line = ''.join(line[:prefix_size])
            cropped_times = times[:prefix_size]
            cropped_times3 = times3[:prefix_size]
            if '!' in cropped_line:
                continue # make no prediction for this case, since this case has ended already
            ground_truth = ''.join(line[prefix_size:prefix_size+predict_size])
            ground_truth_t = times[prefix_size:prefix_size+predict_size]
            
            predicted = ''
            predicted_t = []
            for i in range(predict_size):
                if len(ground_truth)<=i:
                    continue
                enc = encode(cropped_line, cropped_times, cropped_times3)
                y = model.predict(enc, verbose=0)
                y_char = y[0][0]
                y_t = y[1][0][0]
                
                prediction = getSymbol(y_char)              
                cropped_line += prediction
                if y_t<0:
                    y_t=0
                cropped_times.append(y_t)
                y_t = y_t * divisor
                cropped_times3.append(cropped_times3[-1] + timedelta(seconds=y_t))
                predicted_t.append(y_t)
                if i==0:
                    if len(ground_truth_t)>0:
                        one_ahead_pred.append(y_t)
                        one_ahead_gt.append(ground_truth_t[0])
                if i==1:
                    if len(ground_truth_t)>1:
                        two_ahead_pred.append(y_t)
                        two_ahead_gt.append(ground_truth_t[1])
                if i==2:
                    if len(ground_truth_t)>2:
                        three_ahead_pred.append(y_t)
                        three_ahead_gt.append(ground_truth_t[2])
                if prediction == '!': # end of case was just predicted, therefore, stop predicting further into the future
                    print('! predicted, end case')
                    break
                predicted += prediction
            output = []
            if len(ground_truth)>0:
                output.append(prefix_size)
                output.append(unicode(ground_truth).encode("utf-8"))
                output.append(unicode(predicted).encode("utf-8"))
                output.append(1 - distance.nlevenshtein(predicted, ground_truth))
                dls = 1 - (damerau_levenshtein_distance(unicode(predicted), unicode(ground_truth)) / max(len(predicted),len(ground_truth)))
                if dls<0:
                    dls=0 # we encountered problems with Damerau-Levenshtein Similarity on some linux machines where the default character encoding of the operating system caused it to be negative, this should never be the case
                output.append(dls)
                output.append(1 - distance.jaccard(predicted, ground_truth))
                output.append('; '.join(str(x) for x in ground_truth_t))
                output.append('; '.join(str(x) for x in predicted_t))
                if len(predicted_t)>len(ground_truth_t): # if predicted more events than length of case, only use needed number of events for time evaluation
                    predicted_t = predicted_t[:len(ground_truth_t)]
                if len(ground_truth_t)>len(predicted_t): # if predicted less events than length of case, put 0 as placeholder prediction
                    predicted_t.extend(range(len(ground_truth_t)-len(predicted_t)))
                if len(ground_truth_t)>0 and len(predicted_t)>0:
                    output.append('')
                    output.append(metrics.mean_absolute_error([ground_truth_t[0]], [predicted_t[0]]))
                    output.append(metrics.median_absolute_error([ground_truth_t[0]], [predicted_t[0]]))
                else:
                    output.append('')
                    output.append('')
                    output.append('')
                spamwriter.writerow(output)
# Out:
# 2
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 3
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 4
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 5
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 6
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 7
# ! predicted, end case
# 8
# ! predicted, end case
# ! predicted, end case
# 9
# ! predicted, end case
# 10
# 11
# 12
# 13
# 14

# %%
maxlen=9
for prefix_size in range(2,maxlen):
    print(prefix_size)
    for line, times, times3 in izip(lines, lines_t, lines_t3):
        #print('line: {0}'.format(line))
        print('times: {0}, len: {1}'.format(times, len(times)))
        print('times3: {0}, len: {1}'.format(times3, len(times3)))
        times.append(0)
    
        cropped_line = ''.join(line[:prefix_size])
        cropped_times = times[:prefix_size]
        cropped_times3 = times3[:prefix_size]
        
        #print('cropped_line: {0}'.format(cropped_line))
        print('cropped_times: {0}'.format(cropped_times))
        print('cropped_times3: {0}'.format(cropped_times3))   
        
        if '!' in cropped_line:
            continue # make no prediction for this case, since this case has ended already
            
        ground_truth = ''.join(line[prefix_size:prefix_size+predict_size])
        ground_truth_t = times[prefix_size:prefix_size+predict_size]
        #print('ground_truth: {0}'.format(ground_truth))
        print('ground_truth_t: {0}'.format(ground_truth_t))
        
        predicted = ''
        predicted_t = []
        print('\n')
        enc = encode(cropped_line, cropped_times, cropped_times3)
        print(enc)
    break
# Out:
# 2
# times: [0, 834, 345587, 265102], len: 4
# times3: [datetime.datetime(2011, 11, 25, 23, 33, 54), datetime.datetime(2011, 11, 25, 23, 47, 48), datetime.datetime(2011, 11, 29, 23, 47, 35), datetime.datetime(2011, 12, 3, 1, 25, 57)], len: 4
# cropped_times: [0, 834]
# cropped_times3: [datetime.datetime(2011, 11, 25, 23, 33, 54), datetime.datetime(2011, 11, 25, 23, 47, 48)]
# ground_truth_t: [345587]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-a8c7a64af9ff> in <module>()
#      27         predicted_t = []
#      28         print('\n')
# ---> 29         enc = encode(cropped_line, cropped_times, cropped_times3)
#      30         print(enc)
#      31     break
#
# NameError: name 'encode' is not defined

# %%
enc = encode(cropped_line, cropped_times, cropped_times3)
