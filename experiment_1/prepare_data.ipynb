# %%
import pandas as pd
import numpy as np
import pickle
from utils import *

# %%
from keras.models import Sequential, Model
from keras.layers.core import Dense
from keras.layers.recurrent import LSTM, GRU, SimpleRNN
from keras.layers import Input
from keras.layers.wrappers import Bidirectional
from keras.utils.data_utils import get_file
from keras.regularizers import WeightRegularizer
from keras.optimizers import Nadam
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.layers.normalization import BatchNormalization
from theano.ifelse import ifelse
# Out:
# Using Theano backend.

# %%
with open('../input/parameters.pkl', "rb") as f:
    maxlen = pickle.load(f)
    num_features = pickle.load(f)
    chartoindice = pickle.load(f)
    targetchartoindice = pickle.load(f)
    divisor = pickle.load(f)
    divisor2 = pickle.load(f)

# %%
with open('../input/preprocessed_data.pkl', "rb") as f:
    X = pickle.load(f)
    y_a = pickle.load(f)
    y_t = pickle.load(f)
    X_test = pickle.load(f)
    y_a_test = pickle.load(f)
    y_t_test = pickle.load(f)

# %%
# build the model: 
print('Build model...')
main_input = Input(shape=(maxlen, num_features), name='main_input')
# train a 2-layer LSTM with one shared layer
l = LSTM(100, consume_less='gpu', init='glorot_uniform', return_sequences=True, dropout_W=0.2)(main_input) # the shared layer
b = BatchNormalization()(l)
l1 = LSTM(100, consume_less='gpu', init='glorot_uniform', return_sequences=True, dropout_W=0.2)(b) # the shared layer
b1 = BatchNormalization()(l1)

l2_1 = LSTM(100, consume_less='gpu', init='glorot_uniform', return_sequences=False, dropout_W=0.2)(b1) # the layer specialized in activity prediction
b2_1 = BatchNormalization()(l2_1)

l2_2 = LSTM(100, consume_less='gpu', init='glorot_uniform', return_sequences=False, dropout_W=0.2)(b1) # the layer specialized in time prediction
b2_2 = BatchNormalization()(l2_2)
act_output = Dense(len(targetchartoindice), activation='softmax', init='glorot_uniform', name='act_output')(b2_1)
time_output = Dense(1, init='glorot_uniform', name='time_output')(b2_2)

model = Model(input=[main_input], output=[act_output, time_output])

opt = Nadam(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=1e-08, schedule_decay=0.004, clipvalue=3)

model.compile(loss={'act_output':'categorical_crossentropy', 'time_output':'mae'}, optimizer=opt)
early_stopping = EarlyStopping(monitor='val_loss', patience=42)
model_checkpoint = ModelCheckpoint('output_files/models/model_{epoch:02d}-{val_loss:.2f}.h5', monitor='val_loss', verbose=0, save_best_only=True, save_weights_only=False, mode='auto')
lr_reducer = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=0, mode='auto', epsilon=0.0001, cooldown=0, min_lr=0)

model.fit(X, {'act_output':y_a, 'time_output':y_t}, validation_split=0.2, verbose=2, callbacks=[early_stopping, model_checkpoint, lr_reducer], batch_size=maxlen, nb_epoch=500)
# Out:
# Build model...
# Train on 7344 samples, validate on 1837 samples
# Epoch 1/500
# 24s - loss: 2.2196 - act_output_loss: 1.0416 - time_output_loss: 1.1780 - val_loss: 1.8102 - val_act_output_loss: 0.7149 - val_time_output_loss: 1.0953
# Epoch 2/500
# 24s - loss: 1.7545 - act_output_loss: 0.7206 - time_output_loss: 1.0340 - val_loss: 1.5865 - val_act_output_loss: 0.5773 - val_time_output_loss: 1.0092
# Epoch 3/500
# 25s - loss: 1.7045 - act_output_loss: 0.6914 - time_output_loss: 1.0131 - val_loss: 1.6175 - val_act_output_loss: 0.6147 - val_time_output_loss: 1.0028
# Epoch 4/500
# 24s - loss: 1.6851 - act_output_loss: 0.6751 - time_output_loss: 1.0100 - val_loss: 1.5607 - val_act_output_loss: 0.5878 - val_time_output_loss: 0.9729
# Epoch 5/500
# 24s - loss: 1.6816 - act_output_loss: 0.6742 - time_output_loss: 1.0074 - val_loss: 1.5588 - val_act_output_loss: 0.5859 - val_time_output_loss: 0.9730
# Epoch 6/500
# 25s - loss: 1.6808 - act_output_loss: 0.6752 - time_output_loss: 1.0056 - val_loss: 1.5515 - val_act_output_loss: 0.5804 - val_time_output_loss: 0.9711
# Epoch 7/500
# 25s - loss: 1.6764 - act_output_loss: 0.6741 - time_output_loss: 1.0023 - val_loss: 1.5656 - val_act_output_loss: 0.5844 - val_time_output_loss: 0.9813
# Epoch 8/500
# 25s - loss: 1.6584 - act_output_loss: 0.6559 - time_output_loss: 1.0025 - val_loss: 1.5456 - val_act_output_loss: 0.5729 - val_time_output_loss: 0.9727
# Epoch 9/500
# 25s - loss: 1.6593 - act_output_loss: 0.6602 - time_output_loss: 0.9991 - val_loss: 1.5560 - val_act_output_loss: 0.5797 - val_time_output_loss: 0.9763
# Epoch 10/500
# 24s - loss: 1.6612 - act_output_loss: 0.6607 - time_output_loss: 1.0005 - val_loss: 1.5389 - val_act_output_loss: 0.5809 - val_time_output_loss: 0.9580
# Epoch 11/500
# 24s - loss: 1.6583 - act_output_loss: 0.6583 - time_output_loss: 1.0000 - val_loss: 1.5313 - val_act_output_loss: 0.5718 - val_time_output_loss: 0.9594
# Epoch 12/500
# 25s - loss: 1.6626 - act_output_loss: 0.6613 - time_output_loss: 1.0013 - val_loss: 1.5373 - val_act_output_loss: 0.5859 - val_time_output_loss: 0.9514
# Epoch 13/500
# 25s - loss: 1.6617 - act_output_loss: 0.6629 - time_output_loss: 0.9988 - val_loss: 1.5159 - val_act_output_loss: 0.5621 - val_time_output_loss: 0.9537
# Epoch 14/500
# 24s - loss: 1.6459 - act_output_loss: 0.6484 - time_output_loss: 0.9975 - val_loss: 1.5308 - val_act_output_loss: 0.5778 - val_time_output_loss: 0.9529
# Epoch 15/500
# 25s - loss: 1.6541 - act_output_loss: 0.6595 - time_output_loss: 0.9946 - val_loss: 1.5406 - val_act_output_loss: 0.5795 - val_time_output_loss: 0.9611
# Epoch 16/500
# 26s - loss: 1.6487 - act_output_loss: 0.6561 - time_output_loss: 0.9926 - val_loss: 1.5289 - val_act_output_loss: 0.5750 - val_time_output_loss: 0.9539
# Epoch 17/500
# 25s - loss: 1.6442 - act_output_loss: 0.6499 - time_output_loss: 0.9943 - val_loss: 1.5286 - val_act_output_loss: 0.5718 - val_time_output_loss: 0.9568
# Epoch 18/500
# Epoch 79/500
# 25s - loss: 1.5897 - act_output_loss: 0.6039 - time_output_loss: 0.9858 - val_loss: 1.5121 - val_act_output_loss: 0.5603 - val_time_output_loss: 0.9518
# Epoch 80/500
# 25s - loss: 1.5926 - act_output_loss: 0.6094 - time_output_loss: 0.9832 - val_loss: 1.5100 - val_act_output_loss: 0.5607 - val_time_output_loss: 0.9493
# Epoch 81/500
# 25s - loss: 1.5774 - act_output_loss: 0.5978 - time_output_loss: 0.9796 - val_loss: 1.5121 - val_act_output_loss: 0.5606 - val_time_output_loss: 0.9515
# Epoch 82/500
# 25s - loss: 1.5841 - act_output_loss: 0.6007 - time_output_loss: 0.9833 - val_loss: 1.5107 - val_act_output_loss: 0.5617 - val_time_output_loss: 0.9490
# Epoch 83/500
# 25s - loss: 1.5930 - act_output_loss: 0.6061 - time_output_loss: 0.9869 - val_loss: 1.5156 - val_act_output_loss: 0.5621 - val_time_output_loss: 0.9536
# Epoch 84/500
# 25s - loss: 1.5810 - act_output_loss: 0.5978 - time_output_loss: 0.9833 - val_loss: 1.5175 - val_act_output_loss: 0.5648 - val_time_output_loss: 0.9527
# Epoch 85/500
# 25s - loss: 1.5909 - act_output_loss: 0.6073 - time_output_loss: 0.9836 - val_loss: 1.5123 - val_act_output_loss: 0.5618 - val_time_output_loss: 0.9505
# Epoch 86/500
# 25s - loss: 1.5858 - act_output_loss: 0.6019 - time_output_loss: 0.9839 - val_loss: 1.5119 - val_act_output_loss: 0.5612 - val_time_output_loss: 0.9507
# Epoch 87/500
# 25s - loss: 1.5931 - act_output_loss: 0.6103 - time_output_loss: 0.9828 - val_loss: 1.5106 - val_act_output_loss: 0.5604 - val_time_output_loss: 0.9502
# Epoch 88/500
# 25s - loss: 1.5773 - act_output_loss: 0.5972 - time_output_loss: 0.9801 - val_loss: 1.5116 - val_act_output_loss: 0.5623 - val_time_output_loss: 0.9492
# Epoch 89/500
# 25s - loss: 1.5911 - act_output_loss: 0.6041 - time_output_loss: 0.9869 - val_loss: 1.5133 - val_act_output_loss: 0.5626 - val_time_output_loss: 0.9507
# Epoch 90/500
# 26s - loss: 1.5867 - act_output_loss: 0.6017 - time_output_loss: 0.9850 - val_loss: 1.5141 - val_act_output_loss: 0.5621 - val_time_output_loss: 0.9520
# Epoch 91/500
# 25s - loss: 1.5955 - act_output_loss: 0.6112 - time_output_loss: 0.9843 - val_loss: 1.5121 - val_act_output_loss: 0.5624 - val_time_output_loss: 0.9497
# Epoch 92/500
# 25s - loss: 1.5861 - act_output_loss: 0.6022 - time_output_loss: 0.9840 - val_loss: 1.5104 - val_act_output_loss: 0.5618 - val_time_output_loss: 0.9486
# Epoch 93/500
# 25s - loss: 1.5878 - act_output_loss: 0.6017 - time_output_loss: 0.9861 - val_loss: 1.5097 - val_act_output_loss: 0.5606 - val_time_output_loss: 0.9491
# Epoch 94/500
# 25s - loss: 1.5924 - act_output_loss: 0.6079 - time_output_loss: 0.9845 - val_loss: 1.5122 - val_act_output_loss: 0.5617 - val_time_output_loss: 0.9505
# Epoch 95/500
# 25s - loss: 1.5859 - act_output_loss: 0.6027 - time_output_loss: 0.9831 - val_loss: 1.5112 - val_act_output_loss: 0.5612 - val_time_output_loss: 0.9500
# Epoch 96/500
# 25s - loss: 1.5885 - act_output_loss: 0.6036 - time_output_loss: 0.9849 - val_loss: 1.5143 - val_act_output_loss: 0.5624 - val_time_output_loss: 0.9518
# Epoch 97/500
# 25s - loss: 1.5833 - act_output_loss: 0.6002 - time_output_loss: 0.9832 - val_loss: 1.5124 - val_act_output_loss: 0.5631 - val_time_output_loss: 0.9493
# Epoch 98/500
# 25s - loss: 1.5808 - act_output_loss: 0.6014 - time_output_loss: 0.9794 - val_loss: 1.5113 - val_act_output_loss: 0.5622 - val_time_output_loss: 0.9491
# Epoch 99/500
# 25s - loss: 1.5843 - act_output_loss: 0.6024 - time_output_loss: 0.9819 - val_loss: 1.5136 - val_act_output_loss: 0.5633 - val_time_output_loss: 0.9503
# Epoch 100/500
# 25s - loss: 1.5826 - act_output_loss: 0.6000 - time_output_loss: 0.9826 - val_loss: 1.5118 - val_act_output_loss: 0.5625 - val_time_output_loss: 0.9493
# Epoch 101/500
# 25s - loss: 1.5883 - act_output_loss: 0.6028 - time_output_loss: 0.9855 - val_loss: 1.5125 - val_act_output_loss: 0.5620 - val_time_output_loss: 0.9504
# Epoch 102/500
# 26s - loss: 1.5819 - act_output_loss: 0.6031 - time_output_loss: 0.9788 - val_loss: 1.5113 - val_act_output_loss: 0.5617 - val_time_output_loss: 0.9496
# Epoch 103/500
# 25s - loss: 1.5876 - act_output_loss: 0.6080 - time_output_loss: 0.9796 - val_loss: 1.5127 - val_act_output_loss: 0.5624 - val_time_output_loss: 0.9503
# Epoch 104/500
# 25s - loss: 1.5902 - act_output_loss: 0.6058 - time_output_loss: 0.9843 - val_loss: 1.5110 - val_act_output_loss: 0.5618 - val_time_output_loss: 0.9492
# Epoch 105/500
# 25s - loss: 1.5899 - act_output_loss: 0.6052 - time_output_loss: 0.9847 - val_loss: 1.5120 - val_act_output_loss: 0.5617 - val_time_output_loss: 0.9503
# Epoch 106/500
# 25s - loss: 1.5889 - act_output_loss: 0.6076 - time_output_loss: 0.9813 - val_loss: 1.5153 - val_act_output_loss: 0.5622 - val_time_output_loss: 0.9531
# Epoch 107/500
# 25s - loss: 1.5936 - act_output_loss: 0.6078 - time_output_loss: 0.9858 - val_loss: 1.5149 - val_act_output_loss: 0.5617 - val_time_output_loss: 0.9532
# Epoch 108/500
# 25s - loss: 1.5784 - act_output_loss: 0.5958 - time_output_loss: 0.9826 - val_loss: 1.5161 - val_act_output_loss: 0.5622 - val_time_output_loss: 0.9539
# Epoch 109/500
# 25s - loss: 1.5905 - act_output_loss: 0.6065 - time_output_loss: 0.9841 - val_loss: 1.5136 - val_act_output_loss: 0.5615 - val_time_output_loss: 0.9521
# Epoch 110/500
# 25s - loss: 1.5864 - act_output_loss: 0.6045 - time_output_loss: 0.9819 - val_loss: 1.5132 - val_act_output_loss: 0.5616 - val_time_output_loss: 0.9516
# Epoch 111/500
# 25s - loss: 1.5849 - act_output_loss: 0.6020 - time_output_loss: 0.9828 - val_loss: 1.5134 - val_act_output_loss: 0.5613 - val_time_output_loss: 0.9521
# Epoch 112/500
# 25s - loss: 1.5840 - act_output_loss: 0.5999 - time_output_loss: 0.9840 - val_loss: 1.5131 - val_act_output_loss: 0.5621 - val_time_output_loss: 0.9509
# Epoch 113/500
# 26s - loss: 1.5811 - act_output_loss: 0.5983 - time_output_loss: 0.9828 - val_loss: 1.5130 - val_act_output_loss: 0.5615 - val_time_output_loss: 0.9515
# Epoch 114/500
# 25s - loss: 1.5895 - act_output_loss: 0.6071 - time_output_loss: 0.9824 - val_loss: 1.5133 - val_act_output_loss: 0.5621 - val_time_output_loss: 0.9512
# Epoch 115/500
# 25s - loss: 1.5910 - act_output_loss: 0.6085 - time_output_loss: 0.9825 - val_loss: 1.5129 - val_act_output_loss: 0.5618 - val_time_output_loss: 0.9511
# Epoch 116/500
# 25s - loss: 1.5981 - act_output_loss: 0.6129 - time_output_loss: 0.9852 - val_loss: 1.5131 - val_act_output_loss: 0.5623 - val_time_output_loss: 0.9507
# Epoch 117/500
# 25s - loss: 1.5887 - act_output_loss: 0.6045 - time_output_loss: 0.9842 - val_loss: 1.5116 - val_act_output_loss: 0.5615 - val_time_output_loss: 0.9500
# Epoch 118/500
# 25s - loss: 1.5822 - act_output_loss: 0.6026 - time_output_loss: 0.9796 - val_loss: 1.5121 - val_act_output_loss: 0.5612 - val_time_output_loss: 0.9508
# Epoch 119/500
# 25s - loss: 1.5840 - act_output_loss: 0.6005 - time_output_loss: 0.9835 - val_loss: 1.5128 - val_act_output_loss: 0.5617 - val_time_output_loss: 0.9511

# %%
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# main_input (InputLayer)          (None, 15, 14)        0
# ____________________________________________________________________________________________________
# lstm_1 (LSTM)                    (None, 15, 100)       46000       main_input[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_1 (BatchNorma (None, 15, 100)       400         lstm_1[0][0]
# ____________________________________________________________________________________________________
# lstm_2 (LSTM)                    (None, 15, 100)       80400       batchnormalization_1[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_2 (BatchNorma (None, 15, 100)       400         lstm_2[0][0]
# ____________________________________________________________________________________________________
# lstm_3 (LSTM)                    (None, 100)           80400       batchnormalization_2[0][0]
# ____________________________________________________________________________________________________
# lstm_4 (LSTM)                    (None, 100)           80400       batchnormalization_2[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_3 (BatchNorma (None, 100)           400         lstm_3[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_4 (BatchNorma (None, 100)           400         lstm_4[0][0]
# ____________________________________________________________________________________________________
# act_output (Dense)               (None, 10)            1010        batchnormalization_3[0][0]
# ____________________________________________________________________________________________________
# time_output (Dense)              (None, 1)             101         batchnormalization_4[0][0]
# ====================================================================================================
# Total params: 289,911
# Trainable params: 289,111
# Non-trainable params: 800
# ____________________________________________________________________________________________________
